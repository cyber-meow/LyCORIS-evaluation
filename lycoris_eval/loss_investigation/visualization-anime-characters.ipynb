# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
sns.set(style="white", font_scale=2)

# %%
diversity_metrics = pd.read_csv('all_diversity_anime_characters.csv')

# %%
def ensure_unique_folders(df, threshold):
    """
    Ensures uniqueness of the "Folder" field in the dataframe.
    
    Args:
    - df (pd.DataFrame): The dataframe to process.
    - threshold (int): The maximum allowable value for "Count".
    
    Returns:
    - pd.DataFrame: A dataframe where the "Folder" field is unique, and 
                    the chosen row for each folder has the largest "Count" 
                    below the threshold.
    """

    # Filter rows where Count is less than the threshold
    df = df[df['Count'] <= threshold]

    # Sort by Folder and Count, then drop duplicates on Folder while keeping the last (highest Count)
    df = df.sort_values(by=['Folder', 'Count']).drop_duplicates(
        subset='Folder', keep='last')

    return df

# %%
diversity_metrics_extracted = ensure_unique_folders(diversity_metrics, 1000)
diversity_metrics_extracted
# Out:
#                                   Folder  Count  Vendi (vgg19-gram-resize)  \
# 567                                    .   1000                   3.216775
# 552                   1006_shiomi_shuuko    224                   2.732996
# 124                   1034_kohinata_miho    148                   2.444680
# 493                  1053_hoshino_fumina    188                   2.319661
# 417                   1055_aragaki_ayase    156                   2.511228
# ..                                   ...    ...                        ...
# 168                       974_darjeeling    492                   2.857299
# 57       983_arashio_(kantai_collection)    156                   2.306689
# 370  985_prinz_eugen_(kantai_collection)    689                   2.416562
# 328                   990_shidare_hotaru    178                   2.493769
# 7                      994_shirai_kuroko    180                   2.766951
#
#      Dissimilarity (vgg19-gram-resize)  Var (vgg19-gram-resize)  \
# 567                           0.165044               254.904480
# 552                           0.150337               249.620255
# 124                           0.133626               208.031830
# 493                           0.125389               178.783859
# 417                           0.138751               208.541870
# ..                                 ...                      ...
# 168                           0.152228               190.621170
# 57                            0.121479               191.293152
# 370                           0.122191               252.543533
# 328                           0.136731               187.660492
# 7                             0.151912               225.332596
#
#      Vendi (convnextv2-l-resize)  Dissimilarity (convnextv2-l-resize)  \
# 567                    16.563988                             0.479429
# 552                    14.450378                             0.510663
# 124                     9.677541                             0.424805
# 493                     6.762443                             0.338541
# 417                     8.871154                             0.407219
# ..                           ...                                  ...
# 168                    17.051435                             0.512106
# 57                      9.474133                             0.423971
# 370                    10.233757                             0.406824
# 328                     9.422374                             0.412792
# 7                       9.623468                             0.411466
#
#      Var (convnextv2-l-resize)  Vendi (clip-L-14-padding)  \
# 567                 341.355255                  11.819277
# 552                 344.340668                   6.491939
# 124                 297.788269                   5.508071
# 493                 209.558334                   4.508180
# 417                 295.438354                   4.992758
# ..                         ...                        ...
# 168                 373.934875                   7.042085
# 57                  328.911896                   4.768133
# 370                 286.153412                   6.335799
# 328                 297.263336                   4.805556
# 7                   298.403046                   5.505409
#
#      Dissimilarity (clip-L-14-padding)  ...  Var (clip-L-14-resize)  \
# 567                           0.374800  ...              161.907684
# 552                           0.296162  ...              132.016525
# 124                           0.280784  ...              121.863258
# 493                           0.232013  ...               97.890297
# 417                           0.258852  ...              111.217064
# ..                                 ...  ...                     ...
# 168                           0.297126  ...              132.394608
# 57                            0.246076  ...              102.084457
# 370                           0.274863  ...              116.677002
# 328                           0.242840  ...               98.965538
# 7                             0.269920  ...              113.896011
#
#      Vendi (dinov2-l-fb-resize)  Dissimilarity (dinov2-l-fb-resize)  \
# 567                   28.744497                            0.540120
# 552                   18.528917                            0.535552
# 124                   13.649371                            0.483498
# 493                    7.978379                            0.362608
# 417                   12.171404                            0.456414
# ..                          ...                                 ...
# 168                   25.981228                            0.565763
# 57                    11.751133                            0.445336
# 370                   15.946193                            0.465391
# 328                   11.878180                            0.440325
# 7                     12.545006                            0.450399
#
#      Var (dinov2-l-fb-resize)  Vendi (convnextv2-l-padding)  \
# 567               1062.742310                     18.379179
# 552               1063.050171                     15.399308
# 124                956.629333                     10.307519
# 493                720.910950                      7.072237
# 417                905.746399                      9.742863
# ..                        ...                           ...
# 168               1115.107666                     19.074409
# 57                 887.191040                     10.880054
# 370                927.332703                     11.335552
# 328                876.955750                     10.596054
# 7                  887.129028                      9.513581
#
#      Dissimilarity (convnextv2-l-padding)  Var (convnextv2-l-padding)  \
# 567                              0.508839                  361.878815
# 552                              0.528404                  356.991547
# 124                              0.444111                  315.238922
# 493                              0.349293                  213.256973
# 417                              0.430907                  308.159637
# ..                                    ...                         ...
# 168                              0.542836                  386.584259
# 57                               0.458813                  341.146393
# 370                              0.431689                  300.943451
# 328                              0.443196                  309.847534
# 7                                0.412938                  293.985107
#
#      Vendi (convnextv2-l-crop)  Dissimilarity (convnextv2-l-crop)  \
# 567                  18.280094                           0.503707
# 552                  15.032538                           0.521965
# 124                  10.489759                           0.444669
# 493                   7.508914                           0.361458
# 417                   9.660237                           0.429054
# ..                         ...                                ...
# 168                  19.053520                           0.537657
# 57                   10.044838                           0.436603
# 370                  11.096715                           0.422992
# 328                  10.058344                           0.427149
# 7                    10.138731                           0.423033
#
#      Var (convnextv2-l-crop)
# 567               360.851715
# 552               345.636780
# 124               310.070648
# 493               226.145172
# 417               307.750397
# ..                       ...
# 168               390.193573
# 57                336.541840
# 370               293.678070
# 328               300.689880
# 7                 311.173157
#
# [254 rows x 32 columns]

# %%
diversity_metrics_extracted[diversity_metrics_extracted['Folder']=='.']
# Out:
#     Folder  Count  Vendi (vgg19-gram-resize)  \
# 567      .   1000                   3.216775
#
#      Dissimilarity (vgg19-gram-resize)  Var (vgg19-gram-resize)  \
# 567                           0.165044                254.90448
#
#      Vendi (convnextv2-l-resize)  Dissimilarity (convnextv2-l-resize)  \
# 567                    16.563988                             0.479429
#
#      Var (convnextv2-l-resize)  Vendi (clip-L-14-padding)  \
# 567                 341.355255                  11.819277
#
#      Dissimilarity (clip-L-14-padding)  ...  Var (clip-L-14-resize)  \
# 567                             0.3748  ...              161.907684
#
#      Vendi (dinov2-l-fb-resize)  Dissimilarity (dinov2-l-fb-resize)  \
# 567                   28.744497                             0.54012
#
#      Var (dinov2-l-fb-resize)  Vendi (convnextv2-l-padding)  \
# 567                1062.74231                     18.379179
#
#      Dissimilarity (convnextv2-l-padding)  Var (convnextv2-l-padding)  \
# 567                              0.508839                  361.878815
#
#      Vendi (convnextv2-l-crop)  Dissimilarity (convnextv2-l-crop)  \
# 567                  18.280094                           0.503707
#
#      Var (convnextv2-l-crop)
# 567               360.851715
#
# [1 rows x 32 columns]

# %%
for row in diversity_metrics_extracted.head():
    print(row)
# Out:
# Folder
# Count
# Vendi (vgg19-gram-resize)
# Dissimilarity (vgg19-gram-resize)
# Var (vgg19-gram-resize)
# Vendi (convnextv2-l-resize)
# Dissimilarity (convnextv2-l-resize)
# Var (convnextv2-l-resize)
# Vendi (clip-L-14-padding)
# Dissimilarity (clip-L-14-padding)
# Var (clip-L-14-padding)
# Vendi (dinov2-l-fb-padding)
# Dissimilarity (dinov2-l-fb-padding)
# Var (dinov2-l-fb-padding)
# Vendi (clip-L-14-crop)
# Dissimilarity (clip-L-14-crop)
# Var (clip-L-14-crop)
# Vendi (dinov2-l-fb-crop)
# Dissimilarity (dinov2-l-fb-crop)
# Var (dinov2-l-fb-crop)
# Vendi (clip-L-14-resize)
# Dissimilarity (clip-L-14-resize)
# Var (clip-L-14-resize)
# Vendi (dinov2-l-fb-resize)
# Dissimilarity (dinov2-l-fb-resize)
# Var (dinov2-l-fb-resize)
# Vendi (convnextv2-l-padding)
# Dissimilarity (convnextv2-l-padding)
# Var (convnextv2-l-padding)
# Vendi (convnextv2-l-crop)
# Dissimilarity (convnextv2-l-crop)
# Var (convnextv2-l-crop)

# %%
diversity_metrics_extracted.head()
# Out:
#                   Folder  Count  Vendi (vgg19-gram-resize)  \
# 567                    .   1000                   3.216775
# 552   1006_shiomi_shuuko    224                   2.732996
# 124   1034_kohinata_miho    148                   2.444680
# 493  1053_hoshino_fumina    188                   2.319661
# 417   1055_aragaki_ayase    156                   2.511228
#
#      Dissimilarity (vgg19-gram-resize)  Var (vgg19-gram-resize)  \
# 567                           0.165044               254.904480
# 552                           0.150337               249.620255
# 124                           0.133626               208.031830
# 493                           0.125389               178.783859
# 417                           0.138751               208.541870
#
#      Vendi (convnextv2-l-resize)  Dissimilarity (convnextv2-l-resize)  \
# 567                    16.563988                             0.479429
# 552                    14.450378                             0.510663
# 124                     9.677541                             0.424805
# 493                     6.762443                             0.338541
# 417                     8.871154                             0.407219
#
#      Var (convnextv2-l-resize)  Vendi (clip-L-14-padding)  \
# 567                 341.355255                  11.819277
# 552                 344.340668                   6.491939
# 124                 297.788269                   5.508071
# 493                 209.558334                   4.508180
# 417                 295.438354                   4.992758
#
#      Dissimilarity (clip-L-14-padding)  ...  Var (clip-L-14-resize)  \
# 567                           0.374800  ...              161.907684
# 552                           0.296162  ...              132.016525
# 124                           0.280784  ...              121.863258
# 493                           0.232013  ...               97.890297
# 417                           0.258852  ...              111.217064
#
#      Vendi (dinov2-l-fb-resize)  Dissimilarity (dinov2-l-fb-resize)  \
# 567                   28.744497                            0.540120
# 552                   18.528917                            0.535552
# 124                   13.649371                            0.483498
# 493                    7.978379                            0.362608
# 417                   12.171404                            0.456414
#
#      Var (dinov2-l-fb-resize)  Vendi (convnextv2-l-padding)  \
# 567               1062.742310                     18.379179
# 552               1063.050171                     15.399308
# 124                956.629333                     10.307519
# 493                720.910950                      7.072237
# 417                905.746399                      9.742863
#
#      Dissimilarity (convnextv2-l-padding)  Var (convnextv2-l-padding)  \
# 567                              0.508839                  361.878815
# 552                              0.528404                  356.991547
# 124                              0.444111                  315.238922
# 493                              0.349293                  213.256973
# 417                              0.430907                  308.159637
#
#      Vendi (convnextv2-l-crop)  Dissimilarity (convnextv2-l-crop)  \
# 567                  18.280094                           0.503707
# 552                  15.032538                           0.521965
# 124                  10.489759                           0.444669
# 493                   7.508914                           0.361458
# 417                   9.660237                           0.429054
#
#      Var (convnextv2-l-crop)
# 567               360.851715
# 552               345.636780
# 124               310.070648
# 493               226.145172
# 417               307.750397
#
# [5 rows x 32 columns]

# %%
metrics_avg = {}

for col in diversity_metrics_extracted.columns:
    if col not in 'Folder':
        metrics_avg[col] = {}

# %%
import os
from tqdm import tqdm

common_ref = diversity_metrics_extracted[diversity_metrics_extracted['Folder'] == "."].iloc[0]
print(common_ref)

for index, row in tqdm(diversity_metrics_extracted.iterrows()):
    folder_path = row['Folder']
    if folder_path == '.':
        continue  # Skip the root directory

    parts = folder_path.split(os.path.sep)

    if len(parts) == 2:
        types = ['all_artists', parts[0]]
        reference_rows = [common_ref,
                          diversity_metrics_extracted[
            diversity_metrics_extracted['Folder'] == parts[0]].iloc[0]]
    else:
        types = ['all_charatcters']
        reference_rows = [common_ref]

    for col in diversity_metrics_extracted.columns[1:]:
        for type_, reference_row in zip(types, reference_rows):
            if reference_row[col] == 0:  # Check to avoid division by zero
                ratio = 0
            else:
                ratio = row[col] / reference_row[col]
            # Storing the ratio and the name of the row
            if type_ not in metrics_avg[col]:
                metrics_avg[col][type_] = []
            metrics_avg[col][type_].append((folder_path, ratio))
# Out:
# Folder                                            .
# Count                                          1000
# Vendi (vgg19-gram-resize)                  3.216775
# Dissimilarity (vgg19-gram-resize)          0.165044
# Var (vgg19-gram-resize)                   254.90448
# Vendi (convnextv2-l-resize)               16.563988
# Dissimilarity (convnextv2-l-resize)        0.479429
# Var (convnextv2-l-resize)                341.355255
# Vendi (clip-L-14-padding)                 11.819277
# Dissimilarity (clip-L-14-padding)            0.3748
# Var (clip-L-14-padding)                  154.012848
# Vendi (dinov2-l-fb-padding)               26.747808
# Dissimilarity (dinov2-l-fb-padding)        0.527949
# Var (dinov2-l-fb-padding)               1049.181274
# Vendi (clip-L-14-crop)                     9.952122
# Dissimilarity (clip-L-14-crop)             0.343933
# Var (clip-L-14-crop)                     147.093658
# Vendi (dinov2-l-fb-crop)                  29.251366
# Dissimilarity (dinov2-l-fb-crop)           0.544996
# Var (dinov2-l-fb-crop)                    1082.7323
# Vendi (clip-L-14-resize)                  12.916062
# Dissimilarity (clip-L-14-resize)           0.389575
# Var (clip-L-14-resize)                   161.907684
# Vendi (dinov2-l-fb-resize)                28.744497
# Dissimilarity (dinov2-l-fb-resize)          0.54012
# Var (dinov2-l-fb-resize)                 1062.74231
# Vendi (convnextv2-l-padding)              18.379179
# Dissimilarity (convnextv2-l-padding)       0.508839
# Var (convnextv2-l-padding)               361.878815
# Vendi (convnextv2-l-crop)                 18.280094
# Dissimilarity (convnextv2-l-crop)          0.503707
# Var (convnextv2-l-crop)                  360.851715
# Name: 567, dtype: object
# 254it [00:00, 2649.49it/s]

# %%
metrics_avg
# Out:
# {'Count': {'all_charatcters': [('1006_shiomi_shuuko', 0.224),
#    ('1034_kohinata_miho', 0.148),
#    ('1053_hoshino_fumina', 0.188),
#    ('1055_aragaki_ayase', 0.156),
#    ('1061_taneshima_popura', 0.139),
#    ('1062_kise_yayoi', 0.174),
#    ('1065_shirasaka_koume', 0.535),
#    ('1072_koshimizu_sachiko', 0.387),
#    ('1075_sakuma_mayu', 0.211),
#    ('1093_tainaka_ritsu', 0.449),
#    ('109_asahina_mikuru', 0.279),
#    ('112_honma_meiko', 0.27),
#    ('113_ranka_lee', 0.158),
#    ('1152_kitakami_(kantai_collection)', 0.313),
#    ('1153_kagerou_(kantai_collection)', 0.152),
#    ('1158_erica_hartmann', 0.206),
#    ('1159_sakura_chiyo', 0.14),
#    ('115_hiiragi_kagami', 0.34),
#    ('1162_kirino_ranmaru', 0.219),
#    ('116_souseiseki', 0.21),
#    ('1178_yura_(kantai_collection)', 0.168),
#    ('1180_akiyama_yukari', 0.317),
#    ('1213_nanami_chiaki', 0.178),
#    ('1269_serval_(kemono_friends)', 0.467),
#    ('1276_zuihou_(kantai_collection)', 0.363),
#    ('1289_akagi_miria', 0.175),
#    ('128_akizuki_ritsuko', 0.421),
#    ('1290_mika_(girls_und_panzer)', 0.161),
#    ('1295_tachibana_arisu', 0.248),
#    ('1298_djeeta_(granblue_fantasy)', 0.347),
#    ('1300_hata_no_kokoro', 0.348),
#    ('1366_yuubari_(kantai_collection)', 0.378),
#    ('1369_yahagi_(kantai_collection)', 0.251),
#    ('1398_maou_(maoyuu)', 0.144),
#    ('1418_takagaki_kaede', 0.765),
#    ('1423_wakasagihime', 0.291),
#    ('1431_ushio_(kantai_collection)', 0.523),
#    ('1432_akizuki_(kantai_collection)', 0.156),
#    ('1482_hoshizora_rin', 0.536),
#    ('1511_akaza_akari', 0.219),
#    ('1519_kujou_karen', 0.144),
#    ('1538_anchovy', 0.396),
#    ('153_houraisan_kaguya', 0.831),
#    ('1550_hestia_(danmachi)', 0.736),
#    ('1586_tokitsukaze_(kantai_collection)', 0.269),
#    ('1596_u-511_(kantai_collection)', 0.19),
#    ('15_kagiyama_hina', 0.58),
#    ('1600_yazawa_nico', 0.728),
#    ('1603_kiyoshimo_(kantai_collection)', 0.21),
#    ('1606_hecatia_lapislazuli', 0.228),
#    ('1617_hiei_(kantai_collection)', 0.284),
#    ('1621_m1903_springfield_(girls_frontline)', 0.18),
#    ('1623_atago_(azur_lane)', 0.277),
#    ('163_yagokoro_eirin', 0.428),
#    ('1640_noshiro_(kantai_collection)', 0.182),
#    ('1651_nanasaki_ai', 0.246),
#    ('1666_ro-500_(kantai_collection)', 0.648),
#    ('166_amami_haruka', 0.614),
#    ('1678_d.va_(overwatch)', 0.643),
#    ('1691_jack_the_ripper_(fate', 0.237),
#    ('1700_saratoga_(kantai_collection)', 0.192),
#    ('1724_yuzuki_yukari', 0.445),
#    ('1734_perrine_h_clostermann', 0.242),
#    ('173_kamishirasawa_keine', 0.409),
#    ('1742_kasumi_(kantai_collection)', 0.394),
#    ('1756_kousaka_honoka', 0.508),
#    ('1757_hirasawa_ui', 0.148),
#    ('1763_ahri', 0.207),
#    ('1764_matoi_(pso2)', 0.138),
#    ('1811_hayashimo_(kantai_collection)', 0.154),
#    ('181_chun-li', 0.256),
#    ('182_patchouli_knowledge', 1.0),
#    ('184_tifa_lockhart', 0.249),
#    ('185_c.c.', 0.503),
#    ('1908_takami_chika', 0.177),
#    ('1911_toshinou_kyouko', 0.158),
#    ('1919_futatsuiwa_mamizou', 0.203),
#    ('1921_katou_megumi', 0.224),
#    ('1937_mercy_(overwatch)', 0.154),
#    ('1946_ellen_baker', 0.149),
#    ('1957_kisaragi_(kantai_collection)', 0.228),
#    ('1962_sonoda_umi', 0.819),
#    ('1981_clarisse_(granblue_fantasy)', 0.151),
#    ('1989_shoebill_(kemono_friends)', 0.142),
#    ('19_akiyama_mio', 1.0),
#    ('2017_matsuura_kanan', 0.21),
#    ('2026_i-168_(kantai_collection)', 0.173),
#    ('2033_princess_zelda', 0.193),
#    ('2079_jougasaki_rika', 0.297),
#    ('2121_ujimatsu_chiya', 0.22),
#    ('2122_kafuu_chino', 0.41),
#    ('212_furude_rika', 0.193),
#    ('215_alice_margatroid', 1.0),
#    ('217_minase_iori', 0.648),
#    ('221_hiiragi_tsukasa', 0.182),
#    ('2229_yuigahama_yui', 0.144),
#    ('2241_ohara_mari', 0.143),
#    ('2248_unicorn_(azur_lane)', 0.298),
#    ('226_kyonko', 0.167),
#    ('2276_abigail_williams_(fate', 0.604),
#    ('22_rider', 0.185),
#    ('2318_graf_zeppelin_(kantai_collection)', 0.276),
#    ('2320_hk416_(girls_frontline)', 0.177),
#    ('232_hong_meiling', 1.0),
#    ('235_chen', 0.74),
#    ('2369_tokisaki_kurumi', 0.147),
#    ('2370_i-401_(kantai_collection)', 0.402),
#    ('2387_hagikaze_(kantai_collection)', 0.171),
#    ('240_yakumo_yukari', 0.933),
#    ('2479_hassan_of_serenity_(fate)', 0.212),
#    ('247_kallen_stadtfeld', 0.142),
#    ('2505_megumin', 0.181),
#    ('2523_kay_(girls_und_panzer)', 0.178),
#    ('2550_takao_(azur_lane)', 0.165),
#    ('2567_kaguya_luna_(character)', 0.238),
#    ('25_fate_testarossa', 0.515),
#    ('263_hieda_no_akyuu', 0.359),
#    ('2654_libeccio_(kantai_collection)', 0.162),
#    ('2709_tomoe_gozen_(fate', 0.166),
#    ('270_yoko_littner', 0.22),
#    ('271_kochiya_sanae', 1.0),
#    ('275_link', 0.203),
#    ('280_mystia_lorelei', 1.0),
#    ('282_shiki_eiki', 0.142),
#    ('283_komeiji_satori', 1.0),
#    ('285_ibuki_fuuko', 0.164),
#    ('2973_kizuna_ai', 0.253),
#    ('3069_zero_two_(darling_in_the_franxx)', 0.374),
#    ('310_akitsu_maru_(kantai_collection)', 0.141),
#    ('311_mutsu_(kantai_collection)', 0.444),
#    ('3142_tsukino_mito', 0.172),
#    ('3143_natori_sana', 0.203),
#    ('3147_bowsette', 0.368),
#    ('314_naka_(kantai_collection)', 0.275),
#    ('3162_platelet_(hataraku_saibou)', 0.147),
#    ('3175_narmaya_(granblue_fantasy)', 0.226),
#    ('329_kazami_yuuka', 1.0),
#    ('32_tsuruya', 0.15),
#    ('330_katsura_hinagiku', 0.187),
#    ('331_tomoe_mami', 1.0),
#    ('334_nitta_minami', 0.486),
#    ('335_hibiki_(kantai_collection)', 0.699),
#    ('341_hino_akane_(idolmaster)', 0.153),
#    ('346_otonashi_kotori', 0.291),
#    ('34_suigintou', 0.666),
#    ('352_miura_azusa', 0.287),
#    ('353_houjuu_nue', 0.942),
#    ('358_abe_nana', 0.172),
#    ('360_mizuhashi_parsee', 1.0),
#    ('362_mononobe_no_futo', 0.368),
#    ('363_nagae_iku', 0.178),
#    ('367_toyosatomimi_no_miko', 0.55),
#    ('38_yagami_hayate', 0.253),
#    ('391_maekawa_miku', 0.489),
#    ('392_futaba_anzu', 0.366),
#    ('403_hayami_kanade', 0.309),
#    ('407_morikubo_nono', 0.2),
#    ('408_usami_renko', 0.205),
#    ('411_kamiya_nao', 0.198),
#    ('413_hino_akane_(smile_precure!)', 0.137),
#    ('416_super_sonico', 0.774),
#    ('417_akashi_(kantai_collection)', 0.489),
#    ('41_hagiwara_yukiho', 0.438),
#    ('421_kawakaze_(kantai_collection)', 0.154),
#    ('422_mash_kyrielight', 1.0),
#    ('42_asakura_ryouko', 0.358),
#    ('448_meiko', 0.292),
#    ('451_hayasui_(kantai_collection)', 0.184),
#    ('460_gumi', 0.43),
#    ('472_gasai_yuno', 0.165),
#    ('480_lily_white', 0.165),
#    ('483_fusou_(kantai_collection)', 0.137),
#    ('486_waver_velvet', 0.173),
#    ('487_kaenbyou_rin', 1.0),
#    ('492_inubashiri_momiji', 1.0),
#    ('494_fubuki_(kantai_collection)', 0.789),
#    ('49_ayanami_rei', 0.646),
#    ('502_takebe_saori', 0.207),
#    ('510_aegis_(persona)', 0.179),
#    ('519_himekaidou_hatate', 0.522),
#    ('526_haruna_(kantai_collection)', 1.0),
#    ('527_yamashiro_(kantai_collection)', 0.23),
#    ('528_murakumo_(kantai_collection)', 0.669),
#    ('531_sazanami_(kantai_collection)', 0.269),
#    ('532_yuudachi_(kantai_collection)', 0.767),
#    ('542_hamakaze_(kantai_collection)', 1.0),
#    ('544_shijou_takane', 0.544),
#    ('546_toramaru_shou', 0.255),
#    ('548_daiyousei', 0.433),
#    ('549_ganaha_hibiki', 0.507),
#    ('562_makoto_nanaya', 0.193),
#    ('579_cammy_white', 0.185),
#    ('57_kinomoto_sakura', 0.532),
#    ('598_stocking_(psg)', 0.19),
#    ('601_mikasa_ackerman', 0.222),
#    ('608_misaka_mikoto', 0.942),
#    ('616_kirito', 0.177),
#    ('620_leafa', 0.224),
#    ('632_akatsuki_(kantai_collection)', 0.406),
#    ('634_i-8_(kantai_collection)', 0.191),
#    ('640_ryuujou_(kantai_collection)', 0.336),
#    ('641_sendai_(kantai_collection)', 0.499),
#    ('642_makigumo_(kantai_collection)', 0.178),
#    ('644_takao_(kantai_collection)', 0.48),
#    ('645_shiratsuyu_(kantai_collection)', 0.147),
#    ('646_zuikaku_(kantai_collection)', 0.371),
#    ('64_remilia_scarlet', 1.0),
#    ('652_nazrin', 0.725),
#    ('653_roll', 0.155),
#    ('665_gokou_ruri', 0.592),
#    ('670_satonaka_chie', 0.273),
#    ('672_furukawa_nagisa', 0.186),
#    ('679_beatrice', 0.187),
#    ('718_yukikaze_(kantai_collection)', 0.428),
#    ('722_izumi_sagiri', 0.601),
#    ('76_gilgamesh', 0.252),
#    ('771_charlotte_dunois', 0.209),
#    ('778_hoto_cocoa', 0.209),
#    ('779_shimakaze_(kantai_collection)', 0.739),
#    ('780_yamato_(kantai_collection)', 0.456),
#    ('781_z1_leberecht_maass_(kantai_collection)', 0.329),
#    ('788_miyaura_sanshio', 0.142),
#    ('798_weiss_schnee', 0.151),
#    ('803_hiryuu_(kantai_collection)', 0.196),
#    ('809_hoshimiya_ichigo', 0.14),
#    ('818_shoukaku_(kantai_collection)', 0.422),
#    ('826_ayase_eli', 0.676),
#    ('828_samus_aran', 0.291),
#    ('842_maya_(kantai_collection)', 0.36),
#    ('844_ikamusume', 0.273),
#    ('846_shirogane_naoto', 0.186),
#    ('873_ibaraki_kasen', 0.647),
#    ('876_elin_(tera)', 0.145),
#    ('878_akizuki_ryou', 0.175),
#    ('883_aki_minoriko', 0.23),
#    ('887_inaba_tewi', 0.585),
#    ('88_izayoi_sakuya', 1.0),
#    ('909_noire', 0.147),
#    ('913_doremy_sweet', 0.17),
#    ('924_kirishima_(kantai_collection)', 0.242),
#    ('925_toujou_nozomi', 0.837),
#    ('927_tatsuta_(kantai_collection)', 0.23),
#    ('937_nakano_azusa', 1.0),
#    ('942_abukuma_(kantai_collection)', 0.16),
#    ('944_aki_shizuha', 0.203),
#    ('974_darjeeling', 0.492),
#    ('983_arashio_(kantai_collection)', 0.156),
#    ('985_prinz_eugen_(kantai_collection)', 0.689),
#    ('990_shidare_hotaru', 0.178),
#    ('994_shirai_kuroko', 0.18)],
#   'all_artists': [('1691_jack_the_ripper_(fate/apocrypha)', 0.237),
#    ('2276_abigail_williams_(fate/grand_order)', 0.604),
#    ('2709_tomoe_gozen_(fate/grand_order)', 0.166)],
#   '1691_jack_the_ripper_(fate': [('1691_jack_the_ripper_(fate/apocrypha)',
#     1.0)],
#   '2276_abigail_williams_(fate': [('2276_abigail_williams_(fate/grand_order)',
#     1.0)],
#   '2709_tomoe_gozen_(fate': [('2709_tomoe_gozen_(fate/grand_order)', 1.0)]},
#  'Vendi (vgg19-gram-resize)': {'all_charatcters': [('1006_shiomi_shuuko',
#     0.8496073859935552),
#    ('1034_kohinata_miho', 0.7599785563912361),
#    ('1053_hoshino_fumina', 0.7211139054969222),
#    ('1055_aragaki_ayase', 0.7806663913457117),
#    ('1061_taneshima_popura', 0.7597837020865196),
#    ('1062_kise_yayoi', 0.7539080554503914),
#    ('1065_shirasaka_koume', 0.9212745620929296),
#    ('1072_koshimizu_sachiko', 0.8420620995999742),
#    ('1075_sakuma_mayu', 0.8327981078157255),
#    ('1093_tainaka_ritsu', 0.9006597326501105),
#    ('109_asahina_mikuru', 0.8882856319520147),
#    ('112_honma_meiko', 1.0056935405019756),
#    ('113_ranka_lee', 0.884403369311833),
#    ('1152_kitakami_(kantai_collection)', 0.8791855875705933),
#    ('1153_kagerou_(kantai_collection)', 0.7088908557965486),
#    ('1158_erica_hartmann', 0.8774851150285218),
#    ('1159_sakura_chiyo', 0.8002950905016346),
#    ('115_hiiragi_kagami', 0.8259496720014302),
#    ('1162_kirino_ranmaru', 0.9275408067457389),
#    ('116_souseiseki', 0.8739872986715517),
#    ('1178_yura_(kantai_collection)', 0.8441729594700081),
#    ('1180_akiyama_yukari', 0.8453651357694989),
#    ('1213_nanami_chiaki', 0.8810575674771044),
#    ('1269_serval_(kemono_friends)', 0.8628256824051233),
#    ('1276_zuihou_(kantai_collection)', 0.7379265189519344),
#    ('1289_akagi_miria', 0.7916453085398216),
#    ('128_akizuki_ritsuko', 0.9227009489678873),
#    ('1290_mika_(girls_und_panzer)', 0.7805067427445862),
#    ('1295_tachibana_arisu', 0.7811866945861484),
#    ('1298_djeeta_(granblue_fantasy)', 0.8654094104623347),
#    ('1300_hata_no_kokoro', 0.8504891591632813),
#    ('1366_yuubari_(kantai_collection)', 0.7881743967521219),
#    ('1369_yahagi_(kantai_collection)', 0.711336873964767),
#    ('1398_maou_(maoyuu)', 0.8010476031512291),
#    ('1418_takagaki_kaede', 0.9439666762821471),
#    ('1423_wakasagihime', 0.9885842356122813),
#    ('1431_ushio_(kantai_collection)', 0.7904504640185851),
#    ('1432_akizuki_(kantai_collection)', 0.6608057199558972),
#    ('1482_hoshizora_rin', 0.8756067610367286),
#    ('1511_akaza_akari', 0.8106830706963141),
#    ('1519_kujou_karen', 0.7313291924508298),
#    ('1538_anchovy', 0.7408198348489327),
#    ('153_houraisan_kaguya', 1.052892974957553),
#    ('1550_hestia_(danmachi)', 0.6812239162795027),
#    ('1586_tokitsukaze_(kantai_collection)', 0.6961684780433515),
#    ('1596_u-511_(kantai_collection)', 0.8274942018059118),
#    ('15_kagiyama_hina', 1.0352472092624057),
#    ('1600_yazawa_nico', 0.8475426270659078),
#    ('1603_kiyoshimo_(kantai_collection)', 0.7286376237647244),
#    ('1606_hecatia_lapislazuli', 0.7984572045396533),
#    ('1617_hiei_(kantai_collection)', 0.8319504285905295),
#    ('1621_m1903_springfield_(girls_frontline)', 0.7793602968011281),
#    ('1623_atago_(azur_lane)', 0.6907362009206551),
#    ('163_yagokoro_eirin', 0.9996646934672742),
#    ('1640_noshiro_(kantai_collection)', 0.6866289182465751),
#    ('1651_nanasaki_ai', 0.8276512563025621),
#    ('1666_ro-500_(kantai_collection)', 0.7400803668389844),
#    ('166_amami_haruka', 0.9268978394222648),
#    ('1678_d.va_(overwatch)', 0.8443248998749789),
#    ('1691_jack_the_ripper_(fate', 0.7843130351822826),
#    ('1700_saratoga_(kantai_collection)', 0.714996340089172),
#    ('1724_yuzuki_yukari', 0.8658289883318663),
#    ('1734_perrine_h_clostermann', 0.8981634629723456),
#    ('173_kamishirasawa_keine', 0.9583641784708302),
#    ('1742_kasumi_(kantai_collection)', 0.7676765243624951),
#    ('1756_kousaka_honoka', 0.831565759955506),
#    ('1757_hirasawa_ui', 0.795767414668045),
#    ('1763_ahri', 0.8036823980079649),
#    ('1764_matoi_(pso2)', 0.620126418863972),
#    ('1811_hayashimo_(kantai_collection)', 0.6991847544924701),
#    ('181_chun-li', 0.8839336140500256),
#    ('182_patchouli_knowledge', 1.0138619307904784),
#    ('184_tifa_lockhart', 0.7790749453088658),
#    ('185_c.c.', 0.869786554119097),
#    ('1908_takami_chika', 0.8189586345582744),
#    ('1911_toshinou_kyouko', 0.7566037747036569),
#    ('1919_futatsuiwa_mamizou', 0.8849473159616286),
#    ('1921_katou_megumi', 0.817119192133608),
#    ('1937_mercy_(overwatch)', 0.9240011141308134),
#    ('1946_ellen_baker', 0.7385365040899392),
#    ('1957_kisaragi_(kantai_collection)', 0.7431179149447988),
#    ('1962_sonoda_umi', 0.8442121675062177),
#    ('1981_clarisse_(granblue_fantasy)', 0.6817576347459393),
#    ('1989_shoebill_(kemono_friends)', 0.7697386891856676),
#    ('19_akiyama_mio', 0.965080018487812),
#    ('2017_matsuura_kanan', 0.7379706928452823),
#    ('2026_i-168_(kantai_collection)', 0.6897491071092395),
#    ('2033_princess_zelda', 0.9430222740186651),
#    ('2079_jougasaki_rika', 0.8184527100683568),
#    ('2121_ujimatsu_chiya', 0.7275148212306255),
#    ('2122_kafuu_chino', 0.7580624767086477),
#    ('212_furude_rika', 0.8724615946538323),
#    ('215_alice_margatroid', 1.0730045481322004),
#    ('217_minase_iori', 0.8466174211755414),
#    ('221_hiiragi_tsukasa', 0.8395074255128842),
#    ('2229_yuigahama_yui', 0.8187133805094703),
#    ('2241_ohara_mari', 0.7981538425506065),
#    ('2248_unicorn_(azur_lane)', 0.7357862345254257),
#    ('226_kyonko', 0.8214889240632985),
#    ('2276_abigail_williams_(fate', 0.8440401413208825),
#    ('22_rider', 0.8674494142215629),
#    ('2318_graf_zeppelin_(kantai_collection)', 0.7671878691966546),
#    ('2320_hk416_(girls_frontline)', 0.7710307014488148),
#    ('232_hong_meiling', 0.9760959202000099),
#    ('235_chen', 0.9247245728102867),
#    ('2369_tokisaki_kurumi', 0.8490636616955719),
#    ('2370_i-401_(kantai_collection)', 0.7973593054085151),
#    ('2387_hagikaze_(kantai_collection)', 0.6503357660598045),
#    ('240_yakumo_yukari', 1.0100419266576994),
#    ('2479_hassan_of_serenity_(fate)', 0.7458761150572794),
#    ('247_kallen_stadtfeld', 0.772948634063171),
#    ('2505_megumin', 0.7387733087698816),
#    ('2523_kay_(girls_und_panzer)', 0.8098408020318804),
#    ('2550_takao_(azur_lane)', 0.7213017186609203),
#    ('2567_kaguya_luna_(character)', 0.6374921324517133),
#    ('25_fate_testarossa', 0.8487370268835199),
#    ('263_hieda_no_akyuu', 0.9846114016672828),
#    ('2654_libeccio_(kantai_collection)', 0.6396891907075918),
#    ('2709_tomoe_gozen_(fate', 0.6999520905962082),
#    ('270_yoko_littner', 0.7530894301953168),
#    ('271_kochiya_sanae', 0.9802255121725758),
#    ('275_link', 0.9936648262854232),
#    ('280_mystia_lorelei', 1.0908135941747383),
#    ('282_shiki_eiki', 0.9406185768120264),
#    ('283_komeiji_satori', 0.9785706217519959),
#    ('285_ibuki_fuuko', 0.7830620097698422),
#    ('2973_kizuna_ai', 0.6544148100537409),
#    ('3069_zero_two_(darling_in_the_franxx)', 0.8289549049772119),
#    ('310_akitsu_maru_(kantai_collection)', 0.8360348090279579),
#    ('311_mutsu_(kantai_collection)', 0.8087822591714934),
#    ('3142_tsukino_mito', 0.7948204183000878),
#    ('3143_natori_sana', 0.6315102016493761),
#    ('3147_bowsette', 0.7254876397592315),
#    ('314_naka_(kantai_collection)', 0.7912832456723666),
#    ('3162_platelet_(hataraku_saibou)', 0.6621493178394637),
#    ('3175_narmaya_(granblue_fantasy)', 0.67267952907665),
#    ('329_kazami_yuuka', 1.1268430371122962),
#    ('32_tsuruya', 0.7934851956681123),
#    ('330_katsura_hinagiku', 0.8146941491530026),
#    ('331_tomoe_mami', 1.0348894451966524),
#    ('334_nitta_minami', 0.8168142736818762),
#    ('335_hibiki_(kantai_collection)', 0.7793187911295264),
#    ('341_hino_akane_(idolmaster)', 0.7429062360196298),
#    ('346_otonashi_kotori', 0.8454929139442158),
#    ('34_suigintou', 1.053937657888316),
#    ('352_miura_azusa', 0.8172836583573301),
#    ('353_houjuu_nue', 0.907285890769524),
#    ('358_abe_nana', 0.7935056520348304),
#    ('360_mizuhashi_parsee', 1.1023791495665773),
#    ('362_mononobe_no_futo', 0.896542888848108),
#    ('363_nagae_iku', 0.9122808759949874),
#    ('367_toyosatomimi_no_miko', 0.9722985218347997),
#    ('38_yagami_hayate', 0.8922748458138416),
#    ('391_maekawa_miku', 0.8032970623175049),
#    ('392_futaba_anzu', 0.8419404731587269),
#    ('403_hayami_kanade', 0.8297318022088725),
#    ('407_morikubo_nono', 0.8681400389501083),
#    ('408_usami_renko', 0.9317454053962709),
#    ('411_kamiya_nao', 0.793831323322363),
#    ('413_hino_akane_(smile_precure!)', 0.775398951033091),
#    ('416_super_sonico', 0.9003032285779594),
#    ('417_akashi_(kantai_collection)', 0.8082967910482939),
#    ('41_hagiwara_yukiho', 0.9633635366152659),
#    ('421_kawakaze_(kantai_collection)', 0.6700110108617378),
#    ('422_mash_kyrielight', 0.8519743951511889),
#    ('42_asakura_ryouko', 0.8502404216027534),
#    ('448_meiko', 1.0387644443443038),
#    ('451_hayasui_(kantai_collection)', 0.7138835433866197),
#    ('460_gumi', 1.0614117175847375),
#    ('472_gasai_yuno', 0.9681655204677808),
#    ('480_lily_white', 0.8794750155127448),
#    ('483_fusou_(kantai_collection)', 0.7766544975990451),
#    ('486_waver_velvet', 1.0183128952488754),
#    ('487_kaenbyou_rin', 0.9896123162744035),
#    ('492_inubashiri_momiji', 0.9693180440274376),
#    ('494_fubuki_(kantai_collection)', 0.9305651619773657),
#    ('49_ayanami_rei', 1.0688101035477566),
#    ('502_takebe_saori', 0.7852788573370021),
#    ('510_aegis_(persona)', 0.9308345782564237),
#    ('519_himekaidou_hatate', 0.9537926993302467),
#    ('526_haruna_(kantai_collection)', 0.7702494312981818),
#    ('527_yamashiro_(kantai_collection)', 0.7832152842856861),
#    ('528_murakumo_(kantai_collection)', 0.7953394615469223),
#    ('531_sazanami_(kantai_collection)', 0.7696217321324754),
#    ('532_yuudachi_(kantai_collection)', 0.8151745773017933),
#    ('542_hamakaze_(kantai_collection)', 0.7717896623009618),
#    ('544_shijou_takane', 0.9133165907359934),
#    ('546_toramaru_shou', 0.9620879042689473),
#    ('548_daiyousei', 0.8835159632295326),
#    ('549_ganaha_hibiki', 0.7819028156558206),
#    ('562_makoto_nanaya', 0.7397976094511972),
#    ('579_cammy_white', 0.8647781536676339),
#    ('57_kinomoto_sakura', 0.9594656352309627),
#    ('598_stocking_(psg)', 0.944119950797991),
#    ('601_mikasa_ackerman', 0.9527549093056605),
#    ('608_misaka_mikoto', 0.9835850257023872),
#    ('616_kirito', 0.8195305975364012),
#    ('620_leafa', 0.847099998725183),
#    ('632_akatsuki_(kantai_collection)', 0.7373312090335316),
#    ('634_i-8_(kantai_collection)', 0.7030098727169286),
#    ('640_ryuujou_(kantai_collection)', 0.8264641199774803),
#    ('641_sendai_(kantai_collection)', 0.7917530009341741),
#    ('642_makigumo_(kantai_collection)', 0.7750632739140115),
#    ('644_takao_(kantai_collection)', 0.7362814120110891),
#    ('645_shiratsuyu_(kantai_collection)', 0.6951448444174726),
#    ('646_zuikaku_(kantai_collection)', 0.8369076881251977),
#    ('64_remilia_scarlet', 1.0432680320649101),
#    ('652_nazrin', 0.9353478012222235),
#    ('653_roll', 0.7216115288525193),
#    ('665_gokou_ruri', 0.9029249046777781),
#    ('670_satonaka_chie', 0.9599597750748363),
#    ('672_furukawa_nagisa', 0.8869054942539845),
#    ('679_beatrice', 1.0151952263734152),
#    ('718_yukikaze_(kantai_collection)', 0.8343640575114445),
#    ('722_izumi_sagiri', 0.7373704170697413),
#    ('76_gilgamesh', 1.0826097758308324),
#    ('771_charlotte_dunois', 0.7638339144621471),
#    ('778_hoto_cocoa', 0.7428958596017292),
#    ('779_shimakaze_(kantai_collection)', 0.8132938515573372),
#    ('780_yamato_(kantai_collection)', 0.7564102545098136),
#    ('781_z1_leberecht_maass_(kantai_collection)', 0.7933871385189531),
#    ('788_miyaura_sanshio', 0.8042975713549202),
#    ('798_weiss_schnee', 0.9371321745147468),
#    ('803_hiryuu_(kantai_collection)', 0.7531192253381452),
#    ('809_hoshimiya_ichigo', 0.7447248514912247),
#    ('818_shoukaku_(kantai_collection)', 0.8388026443856316),
#    ('826_ayase_eli', 0.9075890304067585),
#    ('828_samus_aran', 0.9133466823479047),
#    ('842_maya_(kantai_collection)', 0.7426798077575879),
#    ('844_ikamusume', 0.7894469161730704),
#    ('846_shirogane_naoto', 0.956131988628632),
#    ('873_ibaraki_kasen', 0.8937812052239038),
#    ('876_elin_(tera)', 0.8368228238502262),
#    ('878_akizuki_ryou', 0.9013672561163796),
#    ('883_aki_minoriko', 0.9953485483243123),
#    ('887_inaba_tewi', 0.9899884614232947),
#    ('88_izayoi_sakuya', 1.1249949229669558),
#    ('909_noire', 0.6841662236924454),
#    ('913_doremy_sweet', 0.8828073280042027),
#    ('924_kirishima_(kantai_collection)', 0.776873588251286),
#    ('925_toujou_nozomi', 0.8466048212395194),
#    ('927_tatsuta_(kantai_collection)', 0.7942251824989557),
#    ('937_nakano_azusa', 0.8834279860291909),
#    ('942_abukuma_(kantai_collection)', 0.7402411271991705),
#    ('944_aki_shizuha', 1.1144492953374603),
#    ('974_darjeeling', 0.8882495368411755),
#    ('983_arashio_(kantai_collection)', 0.717081184797184),
#    ('985_prinz_eugen_(kantai_collection)', 0.7512375360691698),
#    ('990_shidare_hotaru', 0.7752387836110705),
#    ('994_shirai_kuroko', 0.860162945337327)],
#   'all_artists': [('1691_jack_the_ripper_(fate/apocrypha)',
#     0.7843130351822826),
#    ('2276_abigail_williams_(fate/grand_order)', 0.8440401413208825),
#    ('2709_tomoe_gozen_(fate/grand_order)', 0.6999520905962082)],
#   '1691_jack_the_ripper_(fate': [('1691_jack_the_ripper_(fate/apocrypha)',
#     1.0)],
#   '2276_abigail_williams_(fate': [('2276_abigail_williams_(fate/grand_order)',
#     1.0)],
#   '2709_tomoe_gozen_(fate': [('2709_tomoe_gozen_(fate/grand_order)', 1.0)]},
#  'Dissimilarity (vgg19-gram-resize)': {'all_charatcters': [('1006_shiomi_shuuko',
#     0.9108915432214242),
#    ('1034_kohinata_miho', 0.8096417662282135),
#    ('1053_hoshino_fumina', 0.7597337497571302),
#    ('1055_aragaki_ayase', 0.840693700988164),
#    ('1061_taneshima_popura', 0.8076507760636249),
#    ('1062_kise_yayoi', 0.7836144362496722),
#    ('1065_shirasaka_koume', 0.9477456270806446),
#    ('1072_koshimizu_sachiko', 0.8599203170560652),
#    ('1075_sakuma_mayu', 0.8900733629134834),
#    ('1093_tainaka_ritsu', 0.9173672269945479),
#    ('109_asahina_mikuru', 0.9438694621184599),
#    ('112_honma_meiko', 1.0737623394080267),
#    ('113_ranka_lee', 0.9766090255813169),
#    ('1152_kitakami_(kantai_collection)', 0.9191252788939157),
#    ('1153_kagerou_(kantai_collection)', 0.7334568688618962),
#    ('1158_erica_hartmann', 0.938083925670664),
#    ('1159_sakura_chiyo', 0.8667018903030508),
#    ('115_hiiragi_kagami', 0.8470946278296583),
#    ('1162_kirino_ranmaru', 0.9982675893670366),
#    ('116_souseiseki', 0.9452995947235333),
#    ('1178_yura_(kantai_collection)', 0.9431316437062971),
#    ('1180_akiyama_yukari', 0.8743317922089555),
#    ('1213_nanami_chiaki', 0.9591877713550221),
#    ('1269_serval_(kemono_friends)', 0.9030283419057027),
#    ('1276_zuihou_(kantai_collection)', 0.7278360143504417),
#    ('1289_akagi_miria', 0.8446359554116438),
#    ('128_akizuki_ritsuko', 0.9498666293002395),
#    ('1290_mika_(girls_und_panzer)', 0.860997250245037),
#    ('1295_tachibana_arisu', 0.8145305806410604),
#    ('1298_djeeta_(granblue_fantasy)', 0.923439512252553),
#    ('1300_hata_no_kokoro', 0.8874149775331949),
#    ('1366_yuubari_(kantai_collection)', 0.8056370337894112),
#    ('1369_yahagi_(kantai_collection)', 0.7222375508040162),
#    ('1398_maou_(maoyuu)', 0.8728821577956314),
#    ('1418_takagaki_kaede', 0.9577984480894373),
#    ('1423_wakasagihime', 1.0512121096117193),
#    ('1431_ushio_(kantai_collection)', 0.8081672128376797),
#    ('1432_akizuki_(kantai_collection)', 0.6533004643597233),
#    ('1482_hoshizora_rin', 0.8911744927904706),
#    ('1511_akaza_akari', 0.8477688847927068),
#    ('1519_kujou_karen', 0.7625365929763153),
#    ('1538_anchovy', 0.7398534619682235),
#    ('153_houraisan_kaguya', 1.0557657818383273),
#    ('1550_hestia_(danmachi)', 0.6339106109338696),
#    ('1586_tokitsukaze_(kantai_collection)', 0.6798106446647748),
#    ('1596_u-511_(kantai_collection)', 0.8891564167810895),
#    ('15_kagiyama_hina', 1.063347651512799),
#    ('1600_yazawa_nico', 0.8501964987753591),
#    ('1603_kiyoshimo_(kantai_collection)', 0.7459625839751474),
#    ('1606_hecatia_lapislazuli', 0.8340977560641599),
#    ('1617_hiei_(kantai_collection)', 0.8753780281071618),
#    ('1621_m1903_springfield_(girls_frontline)', 0.8354126835427134),
#    ('1623_atago_(azur_lane)', 0.668303133218297),
#    ('163_yagokoro_eirin', 1.0401311099345827),
#    ('1640_noshiro_(kantai_collection)', 0.6876131736881602),
#    ('1651_nanasaki_ai', 0.8525226311261865),
#    ('1666_ro-500_(kantai_collection)', 0.7128015647673108),
#    ('166_amami_haruka', 0.9348480700793873),
#    ('1678_d.va_(overwatch)', 0.8558169921422163),
#    ('1691_jack_the_ripper_(fate', 0.8218563987960883),
#    ('1700_saratoga_(kantai_collection)', 0.7324893624858881),
#    ('1724_yuzuki_yukari', 0.8848049855289359),
#    ('1734_perrine_h_clostermann', 0.9617013377518172),
#    ('173_kamishirasawa_keine', 1.0045265863818154),
#    ('1742_kasumi_(kantai_collection)', 0.772520435367035),
#    ('1756_kousaka_honoka', 0.8415337233213461),
#    ('1757_hirasawa_ui', 0.8502391138378335),
#    ('1763_ahri', 0.8610246972344272),
#    ('1764_matoi_(pso2)', 0.5974295894435991),
#    ('1811_hayashimo_(kantai_collection)', 0.7136625334871332),
#    ('181_chun-li', 0.9492526834849301),
#    ('182_patchouli_knowledge', 1.0279565644170008),
#    ('184_tifa_lockhart', 0.8170412578810784),
#    ('185_c.c.', 0.8885153851209872),
#    ('1908_takami_chika', 0.8766842881153815),
#    ('1911_toshinou_kyouko', 0.7940031217338986),
#    ('1919_futatsuiwa_mamizou', 0.9491670922153838),
#    ('1921_katou_megumi', 0.850131853892453),
#    ('1937_mercy_(overwatch)', 1.0712982498210533),
#    ('1946_ellen_baker', 0.7991476265215929),
#    ('1957_kisaragi_(kantai_collection)', 0.7596813837905304),
#    ('1962_sonoda_umi', 0.8346040807894914),
#    ('1981_clarisse_(granblue_fantasy)', 0.6992362514057554),
#    ('1989_shoebill_(kemono_friends)', 0.8389067575210173),
#    ('19_akiyama_mio', 0.9571570552847376),
#    ('2017_matsuura_kanan', 0.7671982474374988),
#    ('2026_i-168_(kantai_collection)', 0.6893762816118897),
#    ('2033_princess_zelda', 1.0201359781637533),
#    ('2079_jougasaki_rika', 0.8784697870041394),
#    ('2121_ujimatsu_chiya', 0.7244116412794056),
#    ('2122_kafuu_chino', 0.7558182200338462),
#    ('212_furude_rika', 0.9222535133952146),
#    ('215_alice_margatroid', 1.0862182165668588),
#    ('217_minase_iori', 0.843697340603415),
#    ('221_hiiragi_tsukasa', 0.894427322177818),
#    ('2229_yuigahama_yui', 0.8988982922916577),
#    ('2241_ohara_mari', 0.863954302207244),
#    ('2248_unicorn_(azur_lane)', 0.7427209500703148),
#    ('226_kyonko', 0.876890862825003),
#    ('2276_abigail_williams_(fate', 0.8435900806580343),
#    ('22_rider', 0.9415205776580065),
#    ('2318_graf_zeppelin_(kantai_collection)', 0.8074138652078353),
#    ('2320_hk416_(girls_frontline)', 0.8283660301613521),
#    ('232_hong_meiling', 0.9817473909108574),
#    ('235_chen', 0.9337137148994542),
#    ('2369_tokisaki_kurumi', 0.9526290243245333),
#    ('2370_i-401_(kantai_collection)', 0.8057435714455969),
#    ('2387_hagikaze_(kantai_collection)', 0.6420630890719811),
#    ('240_yakumo_yukari', 1.0297081157136185),
#    ('2479_hassan_of_serenity_(fate)', 0.7684376956952287),
#    ('247_kallen_stadtfeld', 0.8174096253702634),
#    ('2505_megumin', 0.7650671331691812),
#    ('2523_kay_(girls_und_panzer)', 0.8854568515269556),
#    ('2550_takao_(azur_lane)', 0.7566502971858888),
#    ('2567_kaguya_luna_(character)', 0.6145550662447535),
#    ('25_fate_testarossa', 0.8634501443494956),
#    ('263_hieda_no_akyuu', 1.0304881880436585),
#    ('2654_libeccio_(kantai_collection)', 0.6135059411897693),
#    ('2709_tomoe_gozen_(fate', 0.7166683399699671),
#    ('270_yoko_littner', 0.7843150567683195),
#    ('271_kochiya_sanae', 0.9863743754907054),
#    ('275_link', 1.0861402093338546),
#    ('280_mystia_lorelei', 1.103909245807292),
#    ('282_shiki_eiki', 1.0513926819103396),
#    ('283_komeiji_satori', 0.9961281687729827),
#    ('285_ibuki_fuuko', 0.8149328957223868),
#    ('2973_kizuna_ai', 0.6332063789692502),
#    ('3069_zero_two_(darling_in_the_franxx)', 0.8462033229636685),
#    ('310_akitsu_maru_(kantai_collection)', 0.9271795257015777),
#    ('311_mutsu_(kantai_collection)', 0.8348381024885031),
#    ('3142_tsukino_mito', 0.8744971964344915),
#    ('3143_natori_sana', 0.6337842103248353),
#    ('3147_bowsette', 0.7386519338932039),
#    ('314_naka_(kantai_collection)', 0.8279947735153886),
#    ('3162_platelet_(hataraku_saibou)', 0.6515478296293139),
#    ('3175_narmaya_(granblue_fantasy)', 0.6707278580441707),
#    ('329_kazami_yuuka', 1.1265093135580189),
#    ('32_tsuruya', 0.858891054953929),
#    ('330_katsura_hinagiku', 0.8517226958432983),
#    ('331_tomoe_mami', 1.050220045403099),
#    ('334_nitta_minami', 0.8293678452740981),
#    ('335_hibiki_(kantai_collection)', 0.763828046056048),
#    ('341_hino_akane_(idolmaster)', 0.7821749138850707),
#    ('346_otonashi_kotori', 0.8838075041513572),
#    ('34_suigintou', 1.1099013569647103),
#    ('352_miura_azusa', 0.8542008700695639),
#    ('353_houjuu_nue', 0.9130013499585049),
#    ('358_abe_nana', 0.8715238929654093),
#    ('360_mizuhashi_parsee', 1.1134398517284743),
#    ('362_mononobe_no_futo', 0.9432136235298708),
#    ('363_nagae_iku', 0.9900183244768641),
#    ('367_toyosatomimi_no_miko', 1.0012455877158837),
#    ('38_yagami_hayate', 0.9484711665765013),
#    ('391_maekawa_miku', 0.8215833734805743),
#    ('392_futaba_anzu', 0.8832852890637474),
#    ('403_hayami_kanade', 0.8576653301908939),
#    ('407_morikubo_nono', 0.9545069762301854),
#    ('408_usami_renko', 1.006077341282367),
#    ('411_kamiya_nao', 0.8389840424648264),
#    ('413_hino_akane_(smile_precure!)', 0.8297939958988418),
#    ('416_super_sonico', 0.9100164898623104),
#    ('417_akashi_(kantai_collection)', 0.8369757173595711),
#    ('41_hagiwara_yukiho', 0.9877770611063882),
#    ('421_kawakaze_(kantai_collection)', 0.6744115329360261),
#    ('422_mash_kyrielight', 0.8512214271423278),
#    ('42_asakura_ryouko', 0.8856106991253799),
#    ('448_meiko', 1.0924793804492205),
#    ('451_hayasui_(kantai_collection)', 0.7249237443182929),
#    ('460_gumi', 1.0968416460392916),
#    ('472_gasai_yuno', 1.056457012597446),
#    ('480_lily_white', 0.9707678728655454),
#    ('483_fusou_(kantai_collection)', 0.8380920153096421),
#    ('486_waver_velvet', 1.106515265220981),
#    ('487_kaenbyou_rin', 0.9996218816066892),
#    ('492_inubashiri_momiji', 0.9927908315498812),
#    ('494_fubuki_(kantai_collection)', 0.9613257473706869),
#    ('49_ayanami_rei', 1.09341005007631),
#    ('502_takebe_saori', 0.8224793732263288),
#    ('510_aegis_(persona)', 1.0282866505788788),
#    ('519_himekaidou_hatate', 0.9804776065069594),
#    ('526_haruna_(kantai_collection)', 0.743584807946915),
#    ('527_yamashiro_(kantai_collection)', 0.8219643810306637),
#    ('528_murakumo_(kantai_collection)', 0.7974953899892167),
#    ('531_sazanami_(kantai_collection)', 0.7995279117824874),
#    ('532_yuudachi_(kantai_collection)', 0.8207422677136011),
#    ('542_hamakaze_(kantai_collection)', 0.7521493520704785),
#    ('544_shijou_takane', 0.9438477934426255),
#    ('546_toramaru_shou', 1.0343127093284374),
#    ('548_daiyousei', 0.9083454738108774),
#    ('549_ganaha_hibiki', 0.7719494657587973),
#    ('562_makoto_nanaya', 0.7767628009508214),
#    ('579_cammy_white', 0.9348209842345939),
#    ('57_kinomoto_sakura', 0.9938811270889509),
#    ('598_stocking_(psg)', 1.033329312590151),
#    ('601_mikasa_ackerman', 1.026984724305826),
#    ('608_misaka_mikoto', 0.9826141379442355),
#    ('616_kirito', 0.8615559409369683),
#    ('620_leafa', 0.9241502448199229),
#    ('632_akatsuki_(kantai_collection)', 0.7247814533469801),
#    ('634_i-8_(kantai_collection)', 0.7048079902519849),
#    ('640_ryuujou_(kantai_collection)', 0.8607253083633146),
#    ('641_sendai_(kantai_collection)', 0.7952057332427104),
#    ('642_makigumo_(kantai_collection)', 0.8267549641130615),
#    ('644_takao_(kantai_collection)', 0.7228681092707988),
#    ('645_shiratsuyu_(kantai_collection)', 0.7092897947037422),
#    ('646_zuikaku_(kantai_collection)', 0.8718691472003711),
#    ('64_remilia_scarlet', 1.058828649167526),
#    ('652_nazrin', 0.9493516371045743),
#    ('653_roll', 0.7592776241308152),
#    ('665_gokou_ruri', 0.9086300557535029),
#    ('670_satonaka_chie', 1.0125320786688503),
#    ('672_furukawa_nagisa', 0.9474216803769199),
#    ('679_beatrice', 1.0994079395472838),
#    ('718_yukikaze_(kantai_collection)', 0.853153550737566),
#    ('722_izumi_sagiri', 0.7165816652666293),
#    ('76_gilgamesh', 1.1604749629285072),
#    ('771_charlotte_dunois', 0.785955736673584),
#    ('778_hoto_cocoa', 0.764969262983329),
#    ('779_shimakaze_(kantai_collection)', 0.8192059585969387),
#    ('780_yamato_(kantai_collection)', 0.7598966259704857),
#    ('781_z1_leberecht_maass_(kantai_collection)', 0.8096424885174076),
#    ('788_miyaura_sanshio', 0.8698333751057256),
#    ('798_weiss_schnee', 1.0543161474250033),
#    ('803_hiryuu_(kantai_collection)', 0.7785945263480264),
#    ('809_hoshimiya_ichigo', 0.8100422755865533),
#    ('818_shoukaku_(kantai_collection)', 0.881531209754949),
#    ('826_ayase_eli', 0.9286461339109724),
#    ('828_samus_aran', 0.9729733829208943),
#    ('842_maya_(kantai_collection)', 0.741921375932024),
#    ('844_ikamusume', 0.8129567124862858),
#    ('846_shirogane_naoto', 1.034643156634913),
#    ('873_ibaraki_kasen', 0.910969189309831),
#    ('876_elin_(tera)', 0.9014364165210651),
#    ('878_akizuki_ryou', 0.9704905138148646),
#    ('883_aki_minoriko', 1.0866678415904236),
#    ('887_inaba_tewi', 1.0173735831394595),
#    ('88_izayoi_sakuya', 1.1252648092759274),
#    ('909_noire', 0.6921765968188943),
#    ('913_doremy_sweet', 0.9928312797447719),
#    ('924_kirishima_(kantai_collection)', 0.8093557397071988),
#    ('925_toujou_nozomi', 0.8565815352545749),
#    ('927_tatsuta_(kantai_collection)', 0.8296910696886288),
#    ('937_nakano_azusa', 0.8668181788633624),
#    ('942_abukuma_(kantai_collection)', 0.7908828324137392),
#    ('944_aki_shizuha', 1.2294860840152346),
#    ('974_darjeeling', 0.9223495778580808),
#    ('983_arashio_(kantai_collection)', 0.7360419418889456),
#    ('985_prinz_eugen_(kantai_collection)', 0.7403568975367771),
#    ('990_shidare_hotaru', 0.8284530660092873),
#    ('994_shirai_kuroko', 0.9204373172156912)],
#   'all_artists': [('1691_jack_the_ripper_(fate/apocrypha)',
#     0.8218563987960883),
#    ('2276_abigail_williams_(fate/grand_order)', 0.8435900806580343),
#    ('2709_tomoe_gozen_(fate/grand_order)', 0.7166683399699671)],
#   '1691_jack_the_ripper_(fate': [('1691_jack_the_ripper_(fate/apocrypha)',
#     1.0)],
#   '2276_abigail_williams_(fate': [('2276_abigail_williams_(fate/grand_order)',
#     1.0)],
#   '2709_tomoe_gozen_(fate': [('2709_tomoe_gozen_(fate/grand_order)', 1.0)]},
#  'Var (vgg19-gram-resize)': {'all_charatcters': [('1006_shiomi_shuuko',
#     0.979269781903119),
#    ('1034_kohinata_miho', 0.8161168052045386),
#    ('1053_hoshino_fumina', 0.7013759007555632),
#    ('1055_aragaki_ayase', 0.8181177126944429),
#    ('1061_taneshima_popura', 1.0850036694677536),
#    ('1062_kise_yayoi', 0.8568915956617673),
#    ('1065_shirasaka_koume', 0.8547822203811697),
#    ('1072_koshimizu_sachiko', 0.8259172172863657),
#    ('1075_sakuma_mayu', 0.8931042739422294),
#    ('1093_tainaka_ritsu', 1.047964313378532),
#    ('109_asahina_mikuru', 1.0355536107442973),
#    ('112_honma_meiko', 0.5224792312914013),
#    ('113_ranka_lee', 0.8933573055930351),
#    ('1152_kitakami_(kantai_collection)', 0.9077227031705879),
#    ('1153_kagerou_(kantai_collection)', 0.7853931239082882),
#    ('1158_erica_hartmann', 0.7303038774242131),
#    ('1159_sakura_chiyo', 0.9729230992097174),
#    ('115_hiiragi_kagami', 0.8195834645282788),
#    ('1162_kirino_ranmaru', 0.7906510581595674),
#    ('116_souseiseki', 0.8638583765029554),
#    ('1178_yura_(kantai_collection)', 0.808317719638297),
#    ('1180_akiyama_yukari', 0.8736585491415362),
#    ('1213_nanami_chiaki', 0.793008855808474),
#    ('1269_serval_(kemono_friends)', 1.264335527032544),
#    ('1276_zuihou_(kantai_collection)', 0.8361773005407825),
#    ('1289_akagi_miria', 1.052972149158776),
#    ('128_akizuki_ritsuko', 1.038676788730843),
#    ('1290_mika_(girls_und_panzer)', 0.6239349863696931),
#    ('1295_tachibana_arisu', 0.9143480379421769),
#    ('1298_djeeta_(granblue_fantasy)', 0.987410193817336),
#    ('1300_hata_no_kokoro', 0.992858904475314),
#    ('1366_yuubari_(kantai_collection)', 1.0426173062395319),
#    ('1369_yahagi_(kantai_collection)', 1.0227186146771527),
#    ('1398_maou_(maoyuu)', 1.0639330229350714),
#    ('1418_takagaki_kaede', 0.749308787207984),
#    ('1423_wakasagihime', 0.9065198600214781),
#    ('1431_ushio_(kantai_collection)', 0.8744358417806917),
#    ('1432_akizuki_(kantai_collection)', 0.8803824746698976),
#    ('1482_hoshizora_rin', 1.0479164247292194),
#    ('1511_akaza_akari', 0.819920720341063),
#    ('1519_kujou_karen', 0.7845436391302942),
#    ('1538_anchovy', 0.8350085181934965),
#    ('153_houraisan_kaguya', 1.0768736134739503),
#    ('1550_hestia_(danmachi)', 0.6760777041223747),
#    ('1586_tokitsukaze_(kantai_collection)', 0.7014166659682906),
#    ('1596_u-511_(kantai_collection)', 0.6031187482864843),
#    ('15_kagiyama_hina', 1.4701829705568612),
#    ('1600_yazawa_nico', 1.0176828837586842),
#    ('1603_kiyoshimo_(kantai_collection)', 0.8546715976012575),
#    ('1606_hecatia_lapislazuli', 1.070675026428548),
#    ('1617_hiei_(kantai_collection)', 1.078894993361436),
#    ('1621_m1903_springfield_(girls_frontline)', 0.7159459025873041),
#    ('1623_atago_(azur_lane)', 0.6757614594544764),
#    ('163_yagokoro_eirin', 0.9726067946810077),
#    ('1640_noshiro_(kantai_collection)', 0.8928999689920996),
#    ('1651_nanasaki_ai', 0.6680055933942397),
#    ('1666_ro-500_(kantai_collection)', 0.716806102450582),
#    ('166_amami_haruka', 1.115304853155443),
#    ('1678_d.va_(overwatch)', 0.9927705499173324),
#    ('1691_jack_the_ripper_(fate', 0.6781942028395574),
#    ('1700_saratoga_(kantai_collection)', 0.8553558066783113),
#    ('1724_yuzuki_yukari', 0.7854520868077546),
#    ('1734_perrine_h_clostermann', 0.7197014501880228),
#    ('173_kamishirasawa_keine', 0.9950422677190995),
#    ('1742_kasumi_(kantai_collection)', 0.6501461202412151),
#    ('1756_kousaka_honoka', 1.097157449498426),
#    ('1757_hirasawa_ui', 0.9615552317750766),
#    ('1763_ahri', 0.9911677766856505),
#    ('1764_matoi_(pso2)', 0.5320347527928062),
#    ('1811_hayashimo_(kantai_collection)', 0.6455307319420882),
#    ('181_chun-li', 1.1368242163321844),
#    ('182_patchouli_knowledge', 0.9523771326910667),
#    ('184_tifa_lockhart', 1.0717588662841162),
#    ('185_c.c.', 1.0065899570319095),
#    ('1908_takami_chika', 0.9488561197503564),
#    ('1911_toshinou_kyouko', 0.7893109541693654),
#    ('1919_futatsuiwa_mamizou', 1.1135045991061583),
#    ('1921_katou_megumi', 0.6772290071126617),
#    ('1937_mercy_(overwatch)', 1.0844111671541332),
#    ('1946_ellen_baker', 0.6182912491873895),
#    ('1957_kisaragi_(kantai_collection)', 0.818617131445962),
#    ('1962_sonoda_umi', 0.8755986979076252),
#    ('1981_clarisse_(granblue_fantasy)', 1.0841951893457333),
#    ('1989_shoebill_(kemono_friends)', 0.7031053394646767),
#    ('19_akiyama_mio', 1.1706562301336931),
#    ('2017_matsuura_kanan', 0.6881264882894295),
#    ('2026_i-168_(kantai_collection)', 0.7301177103000104),
#    ('2033_princess_zelda', 0.9285752767664627),
#    ('2079_jougasaki_rika', 1.0964983819622613),
#    ('2121_ujimatsu_chiya', 0.8106192481242614),
#    ('2122_kafuu_chino', 0.6182429415123953),
#    ('212_furude_rika', 0.8256877707953466),
#    ('215_alice_margatroid', 1.004833999983239),
#    ('217_minase_iori', 0.970271145532408),
#    ('221_hiiragi_tsukasa', 1.0054790600894798),
#    ('2229_yuigahama_yui', 0.7760992540145654),
#    ('2241_ohara_mari', 0.7160557471766646),
#    ('2248_unicorn_(azur_lane)', 0.509459863924403),
#    ('226_kyonko', 0.9663366141048834),
#    ('2276_abigail_williams_(fate', 0.8882941584228351),
#    ('22_rider', 0.6870356447188997),
#    ('2318_graf_zeppelin_(kantai_collection)', 0.7537177155677618),
#    ('2320_hk416_(girls_frontline)', 0.7308615407454586),
#    ('232_hong_meiling', 1.3266056166202347),
#    ('235_chen', 1.1918510279897183),
#    ('2369_tokisaki_kurumi', 1.1085591382916442),
#    ('2370_i-401_(kantai_collection)', 0.7124322525264255),
#    ('2387_hagikaze_(kantai_collection)', 0.6904028153736931),
#    ('240_yakumo_yukari', 1.2426206584449837),
#    ('2479_hassan_of_serenity_(fate)', 0.4718492261792879),
#    ('247_kallen_stadtfeld', 0.8760609430951151),
#    ('2505_megumin', 0.9984036917359754),
#    ('2523_kay_(girls_und_panzer)', 0.8942851481734672),
#    ('2550_takao_(azur_lane)', 0.8566128238619561),
#    ('2567_kaguya_luna_(character)', 1.0526050826617948),
#    ('25_fate_testarossa', 1.2332790196235712),
#    ('263_hieda_no_akyuu', 1.1818557091051887),
#    ('2654_libeccio_(kantai_collection)', 0.7693535391507664),
#    ('2709_tomoe_gozen_(fate', 0.8063818808506461),
#    ('270_yoko_littner', 1.3585079572976915),
#    ('271_kochiya_sanae', 1.04017869649491),
#    ('275_link', 1.0292391331675588),
#    ('280_mystia_lorelei', 1.0283030297951203),
#    ('282_shiki_eiki', 1.3133690742286037),
#    ('283_komeiji_satori', 1.0151835751510585),
#    ('285_ibuki_fuuko', 0.8941730887340754),
#    ('2973_kizuna_ai', 0.8405905388789986),
#    ('3069_zero_two_(darling_in_the_franxx)', 0.6533323915232302),
#    ('310_akitsu_maru_(kantai_collection)', 0.8401319452010186),
#    ('311_mutsu_(kantai_collection)', 1.0566951324779623),
#    ('3142_tsukino_mito', 1.0314054959408383),
#    ('3143_natori_sana', 0.6760330479568907),
#    ('3147_bowsette', 1.2629234104859381),
#    ('314_naka_(kantai_collection)', 1.1276993933705348),
#    ('3162_platelet_(hataraku_saibou)', 0.6684134849647599),
#    ('3175_narmaya_(granblue_fantasy)', 0.7869741078045329),
#    ('329_kazami_yuuka', 1.354696020812407),
#    ('32_tsuruya', 1.0753986430751217),
#    ('330_katsura_hinagiku', 0.8394230136087567),
#    ('331_tomoe_mami', 1.2762442369003593),
#    ('334_nitta_minami', 0.8594117956926555),
#    ('335_hibiki_(kantai_collection)', 0.6060683897800834),
#    ('341_hino_akane_(idolmaster)', 1.250355273917088),
#    ('346_otonashi_kotori', 0.9356926674097389),
#    ('34_suigintou', 0.9877398473070416),
#    ('352_miura_azusa', 0.9178555223394564),
#    ('353_houjuu_nue', 1.6207400951308018),
#    ('358_abe_nana', 1.2249709375759483),
#    ('360_mizuhashi_parsee', 1.1295616632206793),
#    ('362_mononobe_no_futo', 1.101226069144026),
#    ('363_nagae_iku', 1.2804373670341722),
#    ('367_toyosatomimi_no_miko', 1.1407951431331866),
#    ('38_yagami_hayate', 1.2371684159991188),
#    ('391_maekawa_miku', 0.9756465266961262),
#    ('392_futaba_anzu', 0.9564769398195316),
#    ('403_hayami_kanade', 0.7054686443082544),
#    ('407_morikubo_nono', 0.8718870282818391),
#    ('408_usami_renko', 1.1089535013187337),
#    ('411_kamiya_nao', 0.9189029069607348),
#    ('413_hino_akane_(smile_precure!)', 1.1268526023290644),
#    ('416_super_sonico', 0.9824086434223145),
#    ('417_akashi_(kantai_collection)', 1.077880352604125),
#    ('41_hagiwara_yukiho', 0.9089733152473868),
#    ('421_kawakaze_(kantai_collection)', 1.0093694142380139),
#    ('422_mash_kyrielight', 0.5992376127029431),
#    ('42_asakura_ryouko', 0.8505856183202817),
#    ('448_meiko', 1.184786135278251),
#    ('451_hayasui_(kantai_collection)', 0.6967514734738786),
#    ('460_gumi', 1.2597556960555316),
#    ('472_gasai_yuno', 0.8945095064954967),
#    ('480_lily_white', 0.9147657466858062),
#    ('483_fusou_(kantai_collection)', 0.98643769507142),
#    ('486_waver_velvet', 0.8460484082411576),
#    ('487_kaenbyou_rin', 1.2630437307173359),
#    ('492_inubashiri_momiji', 1.1219599387504173),
#    ('494_fubuki_(kantai_collection)', 0.9826400054593057),
#    ('49_ayanami_rei', 0.7182716148411713),
#    ('502_takebe_saori', 0.940778621549174),
#    ('510_aegis_(persona)', 1.5150121337865197),
#    ('519_himekaidou_hatate', 1.2472687307472665),
#    ('526_haruna_(kantai_collection)', 1.0628675004878656),
#    ('527_yamashiro_(kantai_collection)', 0.9429602488294219),
#    ('528_murakumo_(kantai_collection)', 0.8492365950691453),
#    ('531_sazanami_(kantai_collection)', 0.8622291447925282),
#    ('532_yuudachi_(kantai_collection)', 1.009250410944472),
#    ('542_hamakaze_(kantai_collection)', 0.5628068614856735),
#    ('544_shijou_takane', 0.8615962364310508),
#    ('546_toramaru_shou', 1.570460964166121),
#    ('548_daiyousei', 1.0903229011901527),
#    ('549_ganaha_hibiki', 0.9669789804746005),
#    ('562_makoto_nanaya', 1.5219982496698679),
#    ('579_cammy_white', 1.1573999336742207),
#    ('57_kinomoto_sakura', 1.0600566762164614),
#    ('598_stocking_(psg)', 1.05117548675819),
#    ('601_mikasa_ackerman', 0.9260168855377476),
#    ('608_misaka_mikoto', 0.7721759165588175),
#    ('616_kirito', 0.6962306844126038),
#    ('620_leafa', 1.2571534268518838),
#    ('632_akatsuki_(kantai_collection)', 0.8132549795216164),
#    ('634_i-8_(kantai_collection)', 0.7999607911683752),
#    ('640_ryuujou_(kantai_collection)', 1.203441517782851),
#    ('641_sendai_(kantai_collection)', 1.0238381315764584),
#    ('642_makigumo_(kantai_collection)', 0.6827130356495078),
#    ('644_takao_(kantai_collection)', 0.883224067398485),
#    ('645_shiratsuyu_(kantai_collection)', 0.8170724232015715),
#    ('646_zuikaku_(kantai_collection)', 0.9800456977436066),
#    ('64_remilia_scarlet', 1.0159681109484227),
#    ('652_nazrin', 1.1090043830086282),
#    ('653_roll', 1.2768083651892619),
#    ('665_gokou_ruri', 0.8732740032875558),
#    ('670_satonaka_chie', 1.3148730172602665),
#    ('672_furukawa_nagisa', 0.9078860633255553),
#    ('679_beatrice', 1.050397415928483),
#    ('718_yukikaze_(kantai_collection)', 0.9281860617691744),
#    ('722_izumi_sagiri', 0.4914430166975748),
#    ('76_gilgamesh', 1.1498914723484952),
#    ('771_charlotte_dunois', 0.8202199645384551),
#    ('778_hoto_cocoa', 0.6516163017751125),
#    ('779_shimakaze_(kantai_collection)', 0.9381495347019109),
#    ('780_yamato_(kantai_collection)', 1.3309498354426286),
#    ('781_z1_leberecht_maass_(kantai_collection)', 0.6581939873406355),
#    ('788_miyaura_sanshio', 0.8775401636115704),
#    ('798_weiss_schnee', 0.6960953989782956),
#    ('803_hiryuu_(kantai_collection)', 0.8629603446067204),
#    ('809_hoshimiya_ichigo', 0.8684881912576876),
#    ('818_shoukaku_(kantai_collection)', 0.8188333486976084),
#    ('826_ayase_eli', 0.9188498104208095),
#    ('828_samus_aran', 0.9332604627719626),
#    ('842_maya_(kantai_collection)', 0.9390342176371502),
#    ('844_ikamusume', 1.175190806337105),
#    ('846_shirogane_naoto', 1.1194898422188726),
#    ('873_ibaraki_kasen', 1.0090171932223195),
#    ('876_elin_(tera)', 1.1390412213521122),
#    ('878_akizuki_ryou', 0.9666575279160895),
#    ('883_aki_minoriko', 1.1506581696239904),
#    ('887_inaba_tewi', 1.023078018990244),
#    ('88_izayoi_sakuya', 1.0133542287473165),
#    ('909_noire', 0.9341423921098662),
#    ('913_doremy_sweet', 1.520036730594023),
#    ('924_kirishima_(kantai_collection)', 1.0735564864576885),
#    ('925_toujou_nozomi', 0.9352234185072869),
#    ('927_tatsuta_(kantai_collection)', 0.8076539829588242),
#    ('937_nakano_azusa', 1.1461337697585574),
#    ('942_abukuma_(kantai_collection)', 0.9749761454665611),
#    ('944_aki_shizuha', 1.150561075387509),
#    ('974_darjeeling', 0.7478141226021255),
#    ('983_arashio_(kantai_collection)', 0.7504503328859735),
# ...
#    ('640_ryuujou_(kantai_collection)', 1.0170847811259436),
#    ('641_sendai_(kantai_collection)', 0.873453932623625),
#    ('642_makigumo_(kantai_collection)', 0.785937088056557),
#    ('644_takao_(kantai_collection)', 0.8879302020780054),
#    ('645_shiratsuyu_(kantai_collection)', 0.9901389170913604),
#    ('646_zuikaku_(kantai_collection)', 1.0464401223269382),
#    ('64_remilia_scarlet', 0.8750308254985684),
#    ('652_nazrin', 1.0156004239127296),
#    ('653_roll', 0.8014402430256273),
#    ('665_gokou_ruri', 0.9116266680677181),
#    ('670_satonaka_chie', 1.0133250169569825),
#    ('672_furukawa_nagisa', 0.8925897631418388),
#    ('679_beatrice', 0.8587006478442977),
#    ('718_yukikaze_(kantai_collection)', 0.9653232665893248),
#    ('722_izumi_sagiri', 0.7844279994452592),
#    ('76_gilgamesh', 1.0439527826727801),
#    ('771_charlotte_dunois', 0.8310089369096118),
#    ('778_hoto_cocoa', 0.8391204804849153),
#    ('779_shimakaze_(kantai_collection)', 0.7634271375146198),
#    ('780_yamato_(kantai_collection)', 0.7576875598464334),
#    ('781_z1_leberecht_maass_(kantai_collection)', 0.9797595398113976),
#    ('788_miyaura_sanshio', 1.1453739979050495),
#    ('798_weiss_schnee', 0.8537381567369512),
#    ('803_hiryuu_(kantai_collection)', 1.0319412514513426),
#    ('809_hoshimiya_ichigo', 0.7561658097059732),
#    ('818_shoukaku_(kantai_collection)', 0.9034246004755054),
#    ('826_ayase_eli', 0.9389870492673116),
#    ('828_samus_aran', 0.8704533868762184),
#    ('842_maya_(kantai_collection)', 0.8801236001910352),
#    ('844_ikamusume', 0.8399275050539617),
#    ('846_shirogane_naoto', 1.0453701639466861),
#    ('873_ibaraki_kasen', 0.8119580688020394),
#    ('876_elin_(tera)', 0.8419650645927318),
#    ('878_akizuki_ryou', 0.9862492243334238),
#    ('883_aki_minoriko', 0.9447526599861126),
#    ('887_inaba_tewi', 0.9219804856252595),
#    ('88_izayoi_sakuya', 0.9437957087119366),
#    ('909_noire', 0.6515149578808908),
#    ('913_doremy_sweet', 0.8757173880424992),
#    ('924_kirishima_(kantai_collection)', 0.9654718916419234),
#    ('925_toujou_nozomi', 0.7830555843496871),
#    ('927_tatsuta_(kantai_collection)', 0.924546161095357),
#    ('937_nakano_azusa', 0.9400443461184012),
#    ('942_abukuma_(kantai_collection)', 0.8376480748085742),
#    ('944_aki_shizuha', 0.9316264408701854),
#    ('974_darjeeling', 1.0674007513611736),
#    ('983_arashio_(kantai_collection)', 0.8667795317742849),
#    ('985_prinz_eugen_(kantai_collection)', 0.8397585268890646),
#    ('990_shidare_hotaru', 0.8480111222658787),
#    ('994_shirai_kuroko', 0.8398404126664518)],
#   'all_artists': [('1691_jack_the_ripper_(fate/apocrypha)', 0.733073902150756),
#    ('2276_abigail_williams_(fate/grand_order)', 0.8638260821820808),
#    ('2709_tomoe_gozen_(fate/grand_order)', 0.8370701410849345)],
#   '1691_jack_the_ripper_(fate': [('1691_jack_the_ripper_(fate/apocrypha)',
#     1.0)],
#   '2276_abigail_williams_(fate': [('2276_abigail_williams_(fate/grand_order)',
#     1.0)],
#   '2709_tomoe_gozen_(fate': [('2709_tomoe_gozen_(fate/grand_order)', 1.0)]},
#  'Var (convnextv2-l-crop)': {'all_charatcters': [('1006_shiomi_shuuko',
#     0.9578360454819272),
#    ('1034_kohinata_miho', 0.8592744200144296),
#    ('1053_hoshino_fumina', 0.6266983435676888),
#    ('1055_aragaki_ayase', 0.8528444894700268),
#    ('1061_taneshima_popura', 0.9879803514583291),
#    ('1062_kise_yayoi', 0.8412402535133104),
#    ('1065_shirasaka_koume', 1.020930552944427),
#    ('1072_koshimizu_sachiko', 0.8248849052581068),
#    ('1075_sakuma_mayu', 0.8873744766008629),
#    ('1093_tainaka_ritsu', 1.1557931661416079),
#    ('109_asahina_mikuru', 0.9312822844376991),
#    ('112_honma_meiko', 0.8960667650565285),
#    ('113_ranka_lee', 0.9224581498460512),
#    ('1152_kitakami_(kantai_collection)', 1.1603867227304514),
#    ('1153_kagerou_(kantai_collection)', 0.8350882231631588),
#    ('1158_erica_hartmann', 1.1047649903940069),
#    ('1159_sakura_chiyo', 0.7772634171626119),
#    ('115_hiiragi_kagami', 0.7866925724449695),
#    ('1162_kirino_ranmaru', 0.9454179831194659),
#    ('116_souseiseki', 1.0593184138309388),
#    ('1178_yura_(kantai_collection)', 0.9560200531291723),
#    ('1180_akiyama_yukari', 1.1528715775504341),
#    ('1213_nanami_chiaki', 0.9648062999280554),
#    ('1269_serval_(kemono_friends)', 0.9292420098831322),
#    ('1276_zuihou_(kantai_collection)', 0.8895018592504018),
#    ('1289_akagi_miria', 0.8892210836433071),
#    ('128_akizuki_ritsuko', 1.1002441648359167),
#    ('1290_mika_(girls_und_panzer)', 1.032304502160746),
#    ('1295_tachibana_arisu', 0.9306938396563239),
#    ('1298_djeeta_(granblue_fantasy)', 0.8778856987874806),
#    ('1300_hata_no_kokoro', 0.6999977334981115),
#    ('1366_yuubari_(kantai_collection)', 0.9659089361826645),
#    ('1369_yahagi_(kantai_collection)', 0.7572319381576502),
#    ('1398_maou_(maoyuu)', 0.6437948717688498),
#    ('1418_takagaki_kaede', 1.0436793816576908),
#    ('1423_wakasagihime', 0.8925803269834915),
#    ('1431_ushio_(kantai_collection)', 0.986087061242657),
#    ('1432_akizuki_(kantai_collection)', 0.8422562890987432),
#    ('1482_hoshizora_rin', 0.9108912096853377),
#    ('1511_akaza_akari', 0.8742118514538045),
#    ('1519_kujou_karen', 0.7616547459661552),
#    ('1538_anchovy', 0.8837961944587579),
#    ('153_houraisan_kaguya', 0.9165981430414714),
#    ('1550_hestia_(danmachi)', 0.5932250706569279),
#    ('1586_tokitsukaze_(kantai_collection)', 0.882416842003422),
#    ('1596_u-511_(kantai_collection)', 0.925791599041608),
#    ('15_kagiyama_hina', 0.9201014107367408),
#    ('1600_yazawa_nico', 0.8465269537394279),
#    ('1603_kiyoshimo_(kantai_collection)', 0.7346081053321233),
#    ('1606_hecatia_lapislazuli', 0.8420007156395142),
#    ('1617_hiei_(kantai_collection)', 1.0811785708335542),
#    ('1621_m1903_springfield_(girls_frontline)', 0.9649720590214006),
#    ('1623_atago_(azur_lane)', 0.7687538865644559),
#    ('163_yagokoro_eirin', 0.9515438810411261),
#    ('1640_noshiro_(kantai_collection)', 0.741738621758807),
#    ('1651_nanasaki_ai', 1.0921023487978956),
#    ('1666_ro-500_(kantai_collection)', 0.8179129593926587),
#    ('166_amami_haruka', 1.0143419672678227),
#    ('1678_d.va_(overwatch)', 0.839372757442266),
#    ('1691_jack_the_ripper_(fate', 0.7374210202319967),
#    ('1700_saratoga_(kantai_collection)', 0.7938438087583213),
#    ('1724_yuzuki_yukari', 0.7893723726443709),
#    ('1734_perrine_h_clostermann', 1.0109425527187919),
#    ('173_kamishirasawa_keine', 0.8531030229130654),
#    ('1742_kasumi_(kantai_collection)', 0.891962451505951),
#    ('1756_kousaka_honoka', 0.8640160603647257),
#    ('1757_hirasawa_ui', 1.166964567894375),
#    ('1763_ahri', 0.6200150806946557),
#    ('1764_matoi_(pso2)', 0.5228764885864293),
#    ('1811_hayashimo_(kantai_collection)', 0.7197167650692141),
#    ('181_chun-li', 0.8056032324376338),
#    ('182_patchouli_knowledge', 0.8176506202561502),
#    ('184_tifa_lockhart', 0.7423268128272843),
#    ('185_c.c.', 0.8150380539747127),
#    ('1908_takami_chika', 0.9094445387410716),
#    ('1911_toshinou_kyouko', 0.8322937447338716),
#    ('1919_futatsuiwa_mamizou', 0.97056955754754),
#    ('1921_katou_megumi', 1.0164566642724626),
#    ('1937_mercy_(overwatch)', 0.9026501919042075),
#    ('1946_ellen_baker', 0.7941562984776634),
#    ('1957_kisaragi_(kantai_collection)', 0.8417841293956076),
#    ('1962_sonoda_umi', 0.8019754762804234),
#    ('1981_clarisse_(granblue_fantasy)', 0.5940786031312063),
#    ('1989_shoebill_(kemono_friends)', 0.6809651221724861),
#    ('19_akiyama_mio', 1.028373643661419),
#    ('2017_matsuura_kanan', 0.7838432920297193),
#    ('2026_i-168_(kantai_collection)', 0.707800208535088),
#    ('2033_princess_zelda', 0.9449119104589673),
#    ('2079_jougasaki_rika', 0.7295282656888233),
#    ('2121_ujimatsu_chiya', 0.873481834875358),
#    ('2122_kafuu_chino', 0.7800883411396563),
#    ('212_furude_rika', 0.8467769455149015),
#    ('215_alice_margatroid', 0.9771691374497237),
#    ('217_minase_iori', 0.8941076786293144),
#    ('221_hiiragi_tsukasa', 0.9270359762352203),
#    ('2229_yuigahama_yui', 0.9513926681539316),
#    ('2241_ohara_mari', 0.8994422460221835),
#    ('2248_unicorn_(azur_lane)', 0.6107737575277674),
#    ('226_kyonko', 0.972241018119414),
#    ('2276_abigail_williams_(fate', 0.90979593110477),
#    ('22_rider', 0.7870285728928573),
#    ('2318_graf_zeppelin_(kantai_collection)', 0.9428842369783335),
#    ('2320_hk416_(girls_frontline)', 0.8826584612532622),
#    ('232_hong_meiling', 0.8275915144537278),
#    ('235_chen', 1.0168585455028585),
#    ('2369_tokisaki_kurumi', 0.8156851910064867),
#    ('2370_i-401_(kantai_collection)', 1.0726429923778726),
#    ('2387_hagikaze_(kantai_collection)', 0.7426183289470601),
#    ('240_yakumo_yukari', 0.815336420342734),
#    ('2479_hassan_of_serenity_(fate)', 0.8019869779317983),
#    ('247_kallen_stadtfeld', 0.7610291745307094),
#    ('2505_megumin', 0.8639412996307886),
#    ('2523_kay_(girls_und_panzer)', 0.9185379472884391),
#    ('2550_takao_(azur_lane)', 0.7867839936592073),
#    ('2567_kaguya_luna_(character)', 0.44532668876167725),
#    ('25_fate_testarossa', 0.8558766123137526),
#    ('263_hieda_no_akyuu', 0.9771656700401179),
#    ('2654_libeccio_(kantai_collection)', 0.7210627119929831),
#    ('2709_tomoe_gozen_(fate', 0.7771357995749294),
#    ('270_yoko_littner', 0.6858241470235799),
#    ('271_kochiya_sanae', 0.8948426848947544),
#    ('275_link', 1.0200133808182392),
#    ('280_mystia_lorelei', 0.8777215465424895),
#    ('282_shiki_eiki', 1.0303570865268388),
#    ('283_komeiji_satori', 0.9060541732854019),
#    ('285_ibuki_fuuko', 0.7751477898773459),
#    ('2973_kizuna_ai', 0.641487987243992),
#    ('3069_zero_two_(darling_in_the_franxx)', 0.7958346938687487),
#    ('310_akitsu_maru_(kantai_collection)', 1.0389407012912042),
#    ('311_mutsu_(kantai_collection)', 0.9493806403020063),
#    ('3142_tsukino_mito', 0.9345119650579832),
#    ('3143_natori_sana', 0.6393975621065917),
#    ('3147_bowsette', 0.5121335233473797),
#    ('314_naka_(kantai_collection)', 0.8595373511476999),
#    ('3162_platelet_(hataraku_saibou)', 0.949071871705168),
#    ('3175_narmaya_(granblue_fantasy)', 0.5582129867344519),
#    ('329_kazami_yuuka', 1.0004494946842497),
#    ('32_tsuruya', 0.9044954458111958),
#    ('330_katsura_hinagiku', 0.7654205219398651),
#    ('331_tomoe_mami', 0.961459657661804),
#    ('334_nitta_minami', 0.9011952330052742),
#    ('335_hibiki_(kantai_collection)', 0.8543406344293984),
#    ('341_hino_akane_(idolmaster)', 0.6568615511549899),
#    ('346_otonashi_kotori', 1.03221494150776),
#    ('34_suigintou', 0.7982341413158853),
#    ('352_miura_azusa', 0.8474643383264877),
#    ('353_houjuu_nue', 0.8628522793017043),
#    ('358_abe_nana', 0.7427757155147721),
#    ('360_mizuhashi_parsee', 0.9188210063116158),
#    ('362_mononobe_no_futo', 0.8964334647650716),
#    ('363_nagae_iku', 0.8815510890245576),
#    ('367_toyosatomimi_no_miko', 0.9049959367879389),
#    ('38_yagami_hayate', 1.0375622791164938),
#    ('391_maekawa_miku', 0.9115199948174912),
#    ('392_futaba_anzu', 0.9305948070551467),
#    ('403_hayami_kanade', 0.9308358343082251),
#    ('407_morikubo_nono', 0.9729407582920351),
#    ('408_usami_renko', 1.0614627106736763),
#    ('411_kamiya_nao', 0.8658970877903289),
#    ('413_hino_akane_(smile_precure!)', 0.9138570288917254),
#    ('416_super_sonico', 0.9288644850909421),
#    ('417_akashi_(kantai_collection)', 0.8288945838977388),
#    ('41_hagiwara_yukiho', 1.1008937544257045),
#    ('421_kawakaze_(kantai_collection)', 0.6397377065318132),
#    ('422_mash_kyrielight', 0.8355439760988919),
#    ('42_asakura_ryouko', 0.7629106248111425),
#    ('448_meiko', 1.1123196302151426),
#    ('451_hayasui_(kantai_collection)', 1.0399613037088005),
#    ('460_gumi', 0.9955272953215594),
#    ('472_gasai_yuno', 0.9433615555103947),
#    ('480_lily_white', 0.8554862327347316),
#    ('483_fusou_(kantai_collection)', 0.813464949436288),
#    ('486_waver_velvet', 1.1838697965704612),
#    ('487_kaenbyou_rin', 0.9067608482772345),
#    ('492_inubashiri_momiji', 0.9080185876834735),
#    ('494_fubuki_(kantai_collection)', 1.1904243847187368),
#    ('49_ayanami_rei', 1.0803273640608406),
#    ('502_takebe_saori', 0.9028951094217215),
#    ('510_aegis_(persona)', 0.9367768600982256),
#    ('519_himekaidou_hatate', 0.8952430438477624),
#    ('526_haruna_(kantai_collection)', 0.8095620839267044),
#    ('527_yamashiro_(kantai_collection)', 0.9512437386828191),
#    ('528_murakumo_(kantai_collection)', 0.8173512390365371),
#    ('531_sazanami_(kantai_collection)', 0.9361544177885215),
#    ('532_yuudachi_(kantai_collection)', 0.8276074137953344),
#    ('542_hamakaze_(kantai_collection)', 0.9736820228089587),
#    ('544_shijou_takane', 0.8202220004771494),
#    ('546_toramaru_shou', 0.897554199206403),
#    ('548_daiyousei', 0.8306387755003662),
#    ('549_ganaha_hibiki', 0.7717685877891872),
#    ('562_makoto_nanaya', 0.7329451864278146),
#    ('579_cammy_white', 0.7879191051647574),
#    ('57_kinomoto_sakura', 1.0599131168637974),
#    ('598_stocking_(psg)', 0.8558923425134272),
#    ('601_mikasa_ackerman', 1.0281510528789268),
#    ('608_misaka_mikoto', 1.056396825239765),
#    ('616_kirito', 1.0144413381528636),
#    ('620_leafa', 0.8438713408363003),
#    ('632_akatsuki_(kantai_collection)', 0.7722227338765665),
#    ('634_i-8_(kantai_collection)', 0.800711394051735),
#    ('640_ryuujou_(kantai_collection)', 1.06099647093816),
#    ('641_sendai_(kantai_collection)', 0.8708947244546843),
#    ('642_makigumo_(kantai_collection)', 0.8543212676781862),
#    ('644_takao_(kantai_collection)', 0.8471848312838828),
#    ('645_shiratsuyu_(kantai_collection)', 1.007909668736372),
#    ('646_zuikaku_(kantai_collection)', 1.0353429678269213),
#    ('64_remilia_scarlet', 0.8605259857401512),
#    ('652_nazrin', 1.1556389932706037),
#    ('653_roll', 0.7795432812638353),
#    ('665_gokou_ruri', 0.936997759461398),
#    ('670_satonaka_chie', 1.0753387764898465),
#    ('672_furukawa_nagisa', 0.9657041898739968),
#    ('679_beatrice', 0.8973640836748519),
#    ('718_yukikaze_(kantai_collection)', 1.0627065804414926),
#    ('722_izumi_sagiri', 0.8052179271165724),
#    ('76_gilgamesh', 1.1139000078566428),
#    ('771_charlotte_dunois', 0.7933404423687345),
#    ('778_hoto_cocoa', 0.8879093033897988),
#    ('779_shimakaze_(kantai_collection)', 0.7573603168840267),
#    ('780_yamato_(kantai_collection)', 0.6713198035010519),
#    ('781_z1_leberecht_maass_(kantai_collection)', 1.1136540754875368),
#    ('788_miyaura_sanshio', 1.1114327344947803),
#    ('798_weiss_schnee', 0.8507842561674857),
#    ('803_hiryuu_(kantai_collection)', 1.0297639903423341),
#    ('809_hoshimiya_ichigo', 0.6907554800505972),
#    ('818_shoukaku_(kantai_collection)', 0.9076699861616528),
#    ('826_ayase_eli', 0.8772174190142087),
#    ('828_samus_aran', 0.7985445167610775),
#    ('842_maya_(kantai_collection)', 0.8491692890008947),
#    ('844_ikamusume', 0.8674284988425195),
#    ('846_shirogane_naoto', 1.0901890152632834),
#    ('873_ibaraki_kasen', 0.7761058097801079),
#    ('876_elin_(tera)', 0.835286372936479),
#    ('878_akizuki_ryou', 1.0426209760182958),
#    ('883_aki_minoriko', 0.9740740938072995),
#    ('887_inaba_tewi', 1.023858991783846),
#    ('88_izayoi_sakuya', 0.9764843663380831),
#    ('909_noire', 0.5659710620142825),
#    ('913_doremy_sweet', 1.0039842227788682),
#    ('924_kirishima_(kantai_collection)', 0.9903606858671513),
#    ('925_toujou_nozomi', 0.692093900158393),
#    ('927_tatsuta_(kantai_collection)', 0.9293008712754629),
#    ('937_nakano_azusa', 0.9967118808422152),
#    ('942_abukuma_(kantai_collection)', 0.8795765261105669),
#    ('944_aki_shizuha', 0.9825619742381615),
#    ('974_darjeeling', 1.0813127849565842),
#    ('983_arashio_(kantai_collection)', 0.9326319524839719),
#    ('985_prinz_eugen_(kantai_collection)', 0.8138469564896758),
#    ('990_shidare_hotaru', 0.8332782353489891),
#    ('994_shirai_kuroko', 0.8623297153028372)],
#   'all_artists': [('1691_jack_the_ripper_(fate/apocrypha)',
#     0.7374210202319967),
#    ('2276_abigail_williams_(fate/grand_order)', 0.90979593110477),
#    ('2709_tomoe_gozen_(fate/grand_order)', 0.7771357995749294)],
#   '1691_jack_the_ripper_(fate': [('1691_jack_the_ripper_(fate/apocrypha)',
#     1.0)],
#   '2276_abigail_williams_(fate': [('2276_abigail_williams_(fate/grand_order)',
#     1.0)],
#   '2709_tomoe_gozen_(fate': [('2709_tomoe_gozen_(fate/grand_order)', 1.0)]}}

# %%
# Convert the nested dictionary structure to a flat dataframe
df_list = []

for metric, categories in metrics_avg.items():
    for category, values in categories.items():
        labels, value_list = zip(*values)
        temp_df = pd.DataFrame({
            'Metric': [metric] * len(labels),
            'Category': category,
            'Diversity Ratio': value_list
        })
        df_list.append(temp_df)

full_df = pd.concat(df_list, ignore_index=True)

# %%
full_df
# Out:
#                        Metric                     Category  Diversity Ratio
# 0                       Count              all_charatcters         0.224000
# 1                       Count              all_charatcters         0.148000
# 2                       Count              all_charatcters         0.188000
# 3                       Count              all_charatcters         0.156000
# 4                       Count              all_charatcters         0.139000
# ...                       ...                          ...              ...
# 7931  Var (convnextv2-l-crop)                  all_artists         0.909796
# 7932  Var (convnextv2-l-crop)                  all_artists         0.777136
# 7933  Var (convnextv2-l-crop)   1691_jack_the_ripper_(fate         1.000000
# 7934  Var (convnextv2-l-crop)  2276_abigail_williams_(fate         1.000000
# 7935  Var (convnextv2-l-crop)       2709_tomoe_gozen_(fate         1.000000
#
# [7936 rows x 3 columns]

# %%
to_replace = {
    'Dissimilarity': 'IntDis',
    'clip-L-14': 'CLIP',
    'convnextv2-l-resize': 'ConvNeXt V2-scale',
    'convnextv2-l': 'ConvNeXt V2',
    'dinov2-l-fb': 'DINOv2',
    'vgg19-gram-resize': 'Vgg19',
    'resize': 'stretch',
    'padding': 'letterbox',
}

def rename_metric(metric_name):
    for key in to_replace:
        metric_name = metric_name.replace(key, to_replace[key])
    return metric_name

# %%
full_df = full_df[full_df['Metric'] != 'Count']
full_df = full_df[full_df['Category'] == 'all_charatcters']
full_df['Metric'] = full_df['Metric'].map(rename_metric)

# Sort the dataframe by Metric
full_df = full_df.sort_values(by='Metric')

# %%
plt.figure(figsize=(15, 15))

full_df_novgg = full_df[full_df['Metric'].apply(lambda x: 'Vgg' not in x)]
sns.violinplot(x='Metric', y='Diversity Ratio', data=full_df_novgg)
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig(f'figures/paper/characters_resizing.pdf',
            bbox_inches='tight',
            pad_inches=0.05)

# %%
plt.figure(figsize=(12, 12))

df_main = full_df[full_df['Metric'].apply(lambda x: not any(
    key in x for key in ['crop', 'stretch', 'ConvNeXt V2-letterbox']))]
sns.violinplot(x='Metric', y='Diversity Ratio', data=df_main)
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig(f'figures/paper/characters_main.pdf',
            bbox_inches='tight',
            pad_inches=0.05)
